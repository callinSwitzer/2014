# %% [markdown]
# # Homework 1. Exploratory Data Analysis
#
# Due: Thursday, September 18, 2014 11:59 PM
#
# <a href=https://github.com/cs109/2014/blob/master/homework/HW1.ipynb download=HW1.ipynb> Download this assignment</a>
#
# ---

# %% [markdown]
# ## Introduction
#
# In this homework we ask you three questions that we expect you to answer using data. For each question we ask you to complete a series of tasks that should help guide you through the data analysis. Complete these tasks and then write a short (100 words or less) answer to the question.
#
# **Note**: We will briefly discuss this homework assignment on Thursday in class.
#
# #### Data
# For this assignment we will use two databases:
#
# 1. The [Sean Lahman's Baseball Database](http://seanlahman.com/baseball-archive/statistics) which contains the "complete batting and pitching statistics from 1871 to 2013, plus fielding statistics, standings, team stats, managerial records, post-season data, and more. For more details on the latest release, please [read the documentation](http://seanlahman.com/files/database/readme2012.txt)."
#
# 2. [Gapminder](http://www.gapminder.org) is a great resource that contains over [500 data sets](http://www.gapminder.org/data/) related to world indicators such as income, GDP and life expectancy.
#
#
# #### Purpose
#
# In this assignment, you will learn how to:
#
# a. Load in CSV files from the web.
#
# b. Create functions in python.
#
# C. Create plots and summary statistics for exploratory data analysis such as histograms, boxplots and scatter plots.
#
#
# #### Useful libraries for this assignment
#
# * [numpy](http://docs.scipy.org/doc/numpy-dev/user/index.html), for arrays
# * [pandas](http://pandas.pydata.org/), for data frames
# * [matplotlib](http://matplotlib.org/), for plotting
#
# ---

# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm
from mpl_toolkits.axes_grid.axislines import Subplot
from urllib import urlopen

# %% [markdown]
# ## Problem 1
#
# In Lecture 1, we showed a plot that provided evidence that the 2002 and 2003 Oakland A's, a team that used data science, had a competitive advantage. Since, others teams have started using data science as well. Use exploratory data analysis to determine if the competitive advantage has since disappeared.

# %% [markdown]
# #### Problem 1(a)
# Load in [these CSV files](http://seanlahman.com/files/database/lahman-csv_2014-02-14.zip) from the [Sean Lahman's Baseball Database](http://seanlahman.com/baseball-archive/statistics). For this assignment, we will use the 'Salaries.csv' and 'Teams.csv' tables. Read these tables into a pandas `DataFrame` and show the head of each table.
#
# **Hint** Use the [requests](http://docs.python-requests.org/en/latest/), [StringIO](http://docs.python.org/2/library/stringio.html) and [zipfile](https://docs.python.org/2/library/zipfile.html) modules to get from the web.

# %%
#your code here
import requests
import StringIO
import zipfile
r = requests.get("http://seanlahman.com/files/database/lahman-csv_2014-02-14.zip")
z = zipfile.ZipFile(StringIO.StringIO(r.content))
z.extractall("data")

# %%
teams = pd.read_csv("data/Teams.csv")
sal = pd.read_csv("data/Salaries.csv")

teams[0:5]
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L ...  DP    FP  \
# 0    1871  NaN    PH1      PNA   NaN     1  28    NaN  21   7 ... NaN  0.84
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9 ... NaN  0.82
# 2    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10 ... NaN  0.83
# 3    1871  NaN    WS3      OLY   NaN     4  32    NaN  15  15 ... NaN  0.85
# 4    1871  NaN    NY2      NNA   NaN     5  33    NaN  16  17 ... NaN  0.83
#
#                       name                      park  attendance  BPF  PPF  \
# 0   Philadelphia Athletics  Jefferson Street Grounds         NaN  102   98
# 1  Chicago White Stockings   Union Base-Ball Grounds         NaN  104  102
# 2     Boston Red Stockings       South End Grounds I         NaN  103   98
# 3      Washington Olympics          Olympics Grounds         NaN   94   98
# 4         New York Mutuals  Union Grounds (Brooklyn)         NaN   90   88
#
#    teamIDBR  teamIDlahman45  teamIDretro
# 0       ATH             PH1          PH1
# 1       CHI             CH1          CH1
# 2       BOS             BS1          BS1
# 3       OLY             WS3          WS3
# 4       NYU             NY2          NY2
#
# [5 rows x 48 columns]

# %%
sal[0:5]
# Out:
#    yearID teamID lgID   playerID   salary
# 0    1985    BAL   AL  murraed02  1472819
# 1    1985    BAL   AL   lynnfr01  1090000
# 2    1985    BAL   AL  ripkeca01   800000
# 3    1985    BAL   AL   lacyle01   725000
# 4    1985    BAL   AL  flanami01   641667

# %% [markdown]
# #### Problem 1(b)
#
# Summarize the Salaries DataFrame to show the total salaries for each team for each year. Show the head of the new summarized DataFrame.

# %%
#your code here
grouped = sal.groupby(["teamID", "yearID"], as_index=False)
salByTeam = grouped.aggregate(np.sum)
salByTeam[0:5]
# Out:
#   teamID  yearID    salary
# 0    ANA    1997  31135472
# 1    ANA    1998  41281000
# 2    ANA    1999  55388166
# 3    ANA    2000  51464167
# 4    ANA    2001  47535167

# %% [markdown]
# #### Problem 1(c)
#
# Merge the new summarized Salaries DataFrame and Teams DataFrame together to create a new DataFrame
# showing wins and total salaries for each team for each year year. Show the head of the new merged DataFrame.
#
# **Hint**: Merge the DataFrames using `teamID` and `yearID`.

# %%
wl = teams[["yearID", "franchID", "W", "L"]]
wl.columns = ["yearID", "teamID", "W", "L"]
merger = pd.merge(salByTeam, wl)
merger[0:5]
# Out:
#   teamID  yearID    salary   W   L
# 0    ANA    1997  31135472  84  78
# 1    ANA    1998  41281000  85  77
# 2    ANA    1999  55388166  70  92
# 3    ANA    2000  51464167  82  80
# 4    ANA    2001  47535167  75  87

# %% [markdown]
# #### Problem 1(d)
#
# How would you graphically display the relationship between total wins and total salaries for a given year? What kind of plot would be best? Choose a plot to show this relationship and specifically annotate the Oakland baseball team on the on the plot. Show this plot across multiple years. In which years can you detect a competitive advantage from the Oakland baseball team of using data science? When did this end?
#
# **Hints**: Use a `for` loop to consider multiple years. Use the `teamID` (three letter representation of the team name) to save space on the plot.

# %% [markdown]
# ### *I would graphically display the relationship with scatterplots. I can detect a competitive advantage from 2000 until 2006.  The advantage looks like it ended in 2007.*

# %%
ss = set(merger.yearID)
for i in ss:

    yr = merger[(merger.yearID == i)] # getting a subset of the data frame for only a certain year
    yr.salary = yr.salary / 1000000 # changing salary to millions of dollars
    ok = yr[(yr.teamID == "OAK")] # the Oakland point
    
    # fitting a linear regression model
    model = sm.ols(formula='W ~ salary', data=yr)
    fitted = model.fit()


    #set figure and axis
    fig = plt.figure(figsize=(6, 4))

    #hide top and right axis
    ax = Subplot(fig, 111)
    fig.add_subplot(ax)

    #plot
    ax.plot(yr.salary, fitted.fittedvalues, '0.09') # plot a line
    ax.scatter(yr.salary, yr.W, s=50, facecolor='0.5', lw = 0) # plot each team
    ax.plot(ok.salary, ok.W, "o" ) # plot the Oakland point

    plt.xlabel("Salary (millions of dollars)") # xlabel
    plt.ylabel("Number of wins per season") # ylabel
    plt.title("Wins vs salary in " + str(i)) # title, according to year


    #do not display top and right axes
    ax.axis["right"].set_visible(False)
    ax.axis["top"].set_visible(False)
    ax.annotate("OAK", (ok.salary+2,ok.W)) # annotate the Oakland point
# Out:
# //anaconda/lib/python2.7/site-packages/pandas/core/generic.py:1858: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
#   self[name] = value
# //anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py:412: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_num_figures`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# #### Problem 1(e):
#
# **For AC209 Students**: Fit a linear regression to the data from each year and obtain the residuals. Plot the residuals against time to detect patterns that support your answer in 1(d).

# %% [markdown]
# ## Discussion for Problem 1
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---
#
#
# I would graphically display the relationship with scatterplots. I can detect a competitive advantage from 2000 until 2006. The advantage looks like it ended in 2007.

# %% [markdown]
# ## Problem 2
#
# Several media reports have demonstrated the income inequality has increased in the US during this last decade. Here we will look at global data. Use exploratory data analysis to determine if the gap between Africa/Latin America/Asia and Europe/NorthAmerica has increased, decreased or stayed the same during the last two decades.

# %% [markdown]
# #### Problem 2(a)
#
# Using the list of countries by continent from [World Atlas](http://www.worldatlas.com/cntycont.htm) data, load in the `countries.csv` file into a pandas DataFrame and name this data set as `countries`.  This data set can be found on Github in the 2014_data repository [here](https://github.com/cs109/2014_data/blob/master/countries.csv).

# %%
page = urlopen("https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv")
countries = pd.read_csv(page)
countries[0:5]
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %% [markdown]
# Using the [data available on Gapminder](http://www.gapminder.org/data/), load in the [Income per person (GDP/capita, PPP$ inflation-adjusted)](https://spreadsheets.google.com/pub?key=phAwcNAVuyj1jiMAkmq1iMg&gid=0) as a pandas DataFrame and name this data set as `income`.
#
# **Hint**: Consider using the pandas function `pandas.read_excel()` to read in the .xlsx file directly.

# %%
page = urlopen("http://spreadsheets.google.com/pub?key=phAwcNAVuyj1jiMAkmq1iMg&output=xls")
inc = pd.read_excel(page)

# %% [markdown]
# Transform the data set to have years as the rows and countries as the columns. Show the head of this data set when it is loaded.

# %%
income = inc.transpose()
income[0:5]
# Out:
#                   0            1                      2         3         4    \
# gdp pc test  Abkhazia  Afghanistan  Akrotiri and Dhekelia   Albania   Algeria
# 1800              NaN     472.0535                    NaN  601.2152  766.2537
# 1801              NaN     472.0535                    NaN  601.8396  766.2348
# 1802              NaN     472.0535                    NaN  602.4647  766.2159
# 1803              NaN     472.0535                    NaN  603.0904   766.197
#
#                         5         6         7         8    \
# gdp pc test  American Samoa   Andorra    Angola  Anguilla
# 1800               674.4537  1260.123  359.9326  775.6687
# 1801               674.4537  1262.214  359.9326  775.6687
# 1802               674.4537  1264.309  359.9326  775.6687
# 1803               674.4537  1266.407  359.9326  775.6687
#
#                              9           ...                      250  \
# gdp pc test  Antigua and Barbuda         ...           Western Sahara
# 1800                    538.3762         ...                      NaN
# 1801                    538.3762         ...                      NaN
# 1802                    538.3762         ...                      NaN
# 1803                    538.3762         ...                      NaN
#
#                  251                    252                           253  \
# gdp pc test  Vietnam  Virgin Islands (U.S.)  Yemen Arab Republic (Former)
# 1800         459.709                    NaN                           NaN
# 1801         459.709                    NaN                           NaN
# 1802         459.709                    NaN                           NaN
# 1803         459.709                    NaN                           NaN
#
#                                    254          255         256       257  \
# gdp pc test  Yemen Democratic (Former)  Yemen, Rep.  Yugoslavia    Zambia
# 1800                               NaN     661.9024         NaN  364.4648
# 1801                               NaN     662.0586         NaN  364.4648
# 1802                               NaN     662.2148         NaN  364.4648
# 1803                               NaN      662.371         NaN  364.4648
#
#                   258    259
# gdp pc test  Zimbabwe  Åland
# 1800         372.8183    NaN
# 1801         372.8183    NaN
# 1802         372.8183    NaN
# 1803         372.8183    NaN
#
# [5 rows x 260 columns]

# %% [markdown]
# #### Problem 2(b)
#
# Graphically display the distribution of income per person across all countries in the world for any given year (e.g. 2000).  What kind of plot would be best?

# %% [markdown]
# *A histogram would be the best plot*

# %%
year = 2000

# transpose
inco = income.transpose()
# rename the column
inco=inco.rename(columns = {'gdp pc test':'Country'})

inco_year = inco[["Country",year]]

# convert to numeric
incoYR = inco_year.convert_objects(convert_numeric=True)

# drop all the ones that don't have a value for the year
inc = incoYR[np.isfinite(incoYR.loc[:,year])]

# %%
income = inc[[2000]].values.T.tolist()
income = income[0]
country = inc.Country.values.T.tolist()

# %%
#set figure and axis
fig = plt.figure(figsize=(8, 6))

#hide top and right axis
ax = Subplot(fig, 111)
fig.add_subplot(ax)

#plot
ax.hist(income, bins = 20, color = "0.75") # plot a line

plt.xlabel("Salary (millions of dollars)") # xlabel
plt.ylabel("Number of countries") # ylabel
plt.title("GDP distribution for countries throughout the world") # title, according to year
#do not display top and right axes
ax.axis["right"].set_visible(False)
ax.axis["top"].set_visible(False)

# %% [markdown]
# #### Problem 2(c)
#
# Write a function to merge the `countries` and `income` data sets for any given year.

# %%
"""
Function
--------
mergeByYear

Return a merged DataFrame containing the income, 
country name and region for a given year. 

Parameters
----------
year : int
    The year of interest

Returns
-------
a DataFrame
   A pandas DataFrame with three columns titled 
   'Country', 'Region', and 'Income'. 

Example
-------
>>> mergeByYear(2010)
"""
def mergeByYear(year):
    me = pd.merge(countries, inco)
    foo = me[["Country", "Region", year]]

    # drop the NaN's
    # convert to numeric
    foo = foo.convert_objects(convert_numeric=True)

    # drop all the ones that don't have a value for the year
    ff = foo[np.isfinite(foo.loc[:,year])]
    ff.columns = ["Country", "Region", "Income"]
    return ff

# %% [markdown]
# #### Problem 2(d)
#
# Use exploratory data analysis tools such as histograms and boxplots to explore the distribution of the income per person by region data set from 2(c) for a given year. Describe how these change through the recent years?
#
# **Hint**: Use a `for` loop to consider multiple years.

# %%
i = 2010
dat = mergeByYear(i)
type(dat.Income)

import pylab as py
#py.boxplot(dat['Income'])

d1 = dat.Income.T.tolist()
d1 = np.asarray(d1)
d1.shape = (-1,1)

d2 = dat.Region.T.tolist()
d2 = np.asarray(d2)
d2.shape = (-1,1)

data = [d1,d2]
data

#py.boxplot(data)

# IDEA: each column in the new dataset becomes a region
#http://glowingpython.blogspot.com/2012/09/boxplot-with-matplotlib.html


#fig, ax = plt.subplots()
#df = pd.DataFrame(dat)
#df.boxplot(ax=ax, positions=["Region"])
#ax.set_xticks(range(10))
#ax.set_xticklabels(range(10))
#plt.show()

#pd.DataFrame.boxplot(dat, column = dat.Income)
# Out:
# [array([[  6300.64821361],
#         [  5497.61810333],
#         [  1438.98621379],
#         [ 13181.34201525],
#         [   468.43218239],
#         [  2017.81591525],
#         [  3655.83933636],
#         [  1759.97344122],
#         [  1022.62454962],
#         [  2165.76384052],
#         [  6059.97599422],
#         [ 13383.76340097],
#         [   561.05000655],
#         [   871.83711562],
#         [ 12542.54602893],
#         [   793.61843434],
#         [  1485.65758612],
#         [   939.37187905],
#         [   595.53685985],
#         [  1471.32564084],
#         [  1801.34954303],
#         [   450.11736334],
#         [ 11842.38609629],
#         [   995.21848714],
#         [   844.42269006],
#         [  1121.55162907],
#         [  1801.64639606],
#         [ 12317.23558664],
#         [  4263.1759894 ],
#         [   954.48755614],
#         [  5159.79421868],
#         [   661.1771297 ],
#         [  2297.34136696],
#         [  1094.05791093],
#         [  1835.45610486],
#         [  1740.51509652],
#         [ 16341.86497758],
#         [   889.5818389 ],
#         [ 24607.28417452],
#         [ 13825.52047065],
#         [  2073.92505171],
#         [  4936.37895253],
#         [  1820.62884881],
#         [  4834.89008848],
#         [  3959.32488191],
#         [ 14486.63660417],
#         [  4095.21484192],
#         [ 10195.44815142],
#         [ 14038.37229315],
#         [  7417.80282829],
#         [  7182.70774985],
#         [  3937.58861864],
#         [  4508.38593246],
#         [  8419.90566007],
#         [  8431.13703853],
#         [ 12097.77465032],
#         [ 10956.60355266]]), array([['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['AFRICA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['ASIA'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['EUROPE'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['NORTH AMERICA'],
#         ['OCEANIA'],
#         ['OCEANIA'],
#         ['OCEANIA'],
#         ['OCEANIA'],
#         ['OCEANIA'],
#         ['OCEANIA'],
#         ['OCEANIA'],
#         ['OCEANIA'],
#         ['OCEANIA'],
#         ['OCEANIA'],
#         ['OCEANIA'],
#         ['OCEANIA'],
#         ['SOUTH AMERICA'],
#         ['SOUTH AMERICA'],
#         ['SOUTH AMERICA'],
#         ['SOUTH AMERICA'],
#         ['SOUTH AMERICA'],
#         ['SOUTH AMERICA'],
#         ['SOUTH AMERICA'],
#         ['SOUTH AMERICA'],
#         ['SOUTH AMERICA'],
#         ['SOUTH AMERICA'],
#         ['SOUTH AMERICA'],
#         ['SOUTH AMERICA']],
#        dtype='|S13')]

# %%
bb = np.unique(d2)

n = len(bb)
be = np.empty((n, 0)).tolist()
for i in range(len(bb)):
    foo = dat.Income[dat.Region == bb[i]]
    be[i] = foo.tolist()
#be
#range(len(bb))
#for i in bb:
    #d[i] = dat.Income[dat.Region == i]
plt = py.boxplot(be)

# %%
import matplotlib.pyplot as plt

#fig,ax1 = plt.subplots(figsize=(10,6))

fig = plt.figure(figsize=(8, 6))

#hide top and right axis
ax1 = Subplot(fig, 111)
fig.add_subplot(ax1)

bp = plt.boxplot(be, notch=0, sym='+', vert=1, whis=1.5)
plt.setp(bp['boxes'], color='black')
plt.setp(bp['whiskers'], color='black')
plt.setp(bp['fliers'], color='red', marker='+')

plt.setp(ax1, xticklabels=np.repeat(bb, 1))

plt.title("Regional GDP for " + str(year))

ax1.axis["right"].set_visible(False)
ax1.axis["top"].set_visible(False)

plt.show()

# %%
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x10f5a4550>,
#   <matplotlib.lines.Line2D at 0x10f0e0710>,
#   <matplotlib.lines.Line2D at 0x10f5b5190>],
#  'caps': [<matplotlib.lines.Line2D at 0x10f5a4dd0>,
#   <matplotlib.lines.Line2D at 0x10f5a4190>,
#   <matplotlib.lines.Line2D at 0x10c733a50>,
#   <matplotlib.lines.Line2D at 0x10f0e00d0>,
#   <matplotlib.lines.Line2D at 0x10f5bf4d0>,
#   <matplotlib.lines.Line2D at 0x10f5bfb10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x10f7ecdd0>,
#   <matplotlib.lines.Line2D at 0x10f90b610>,
#   <matplotlib.lines.Line2D at 0x11062c050>,
#   <matplotlib.lines.Line2D at 0x10f5865d0>,
#   <matplotlib.lines.Line2D at 0x10f5b5e10>,
#   <matplotlib.lines.Line2D at 0x10d8bd810>],
#  'medians': [<matplotlib.lines.Line2D at 0x10f7eced0>,
#   <matplotlib.lines.Line2D at 0x10f0e0850>,
#   <matplotlib.lines.Line2D at 0x10f5b57d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x10f0d6610>,
#   <matplotlib.lines.Line2D at 0x10f0d69d0>,
#   <matplotlib.lines.Line2D at 0x10f90bc90>,
#   <matplotlib.lines.Line2D at 0x10f90b150>,
#   <matplotlib.lines.Line2D at 0x10f586bd0>,
#   <matplotlib.lines.Line2D at 0x10f586e50>]}

# %%
be
# Out:
# [[0      6300.648214
#   1      5497.618103
#   2      1438.986214
#   3     13181.342015
#   4       468.432182
#   5      2017.815915
#   6      3655.839336
#   7      1759.973441
#   8      1022.624550
#   9      2165.763841
#   10     6059.975994
#   11    13383.763401
#   12      561.050007
#   13      871.837116
#   14    12542.546029
#   15      793.618434
#   161     1820.628849
#   162     4834.890088
#   164     3959.324882
#   Name: Income, dtype: float64], [165    14486.636604
#   166     4095.214842
#   167    10195.448151
#   168    14038.372293
#   169     7417.802828
#   170     7182.707750
#   171     3937.588619
#   172     4508.385932
#   173     8419.905660
#   174     8431.137039
#   175    12097.774650
#   176    10956.603553
#   Name: Income, dtype: float64]]

# %%
foo = dat.Income[dat.Region == bb[i]]
len(foo)
be[bb[i]] = foo

i = i + 1
be
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-104-33f2563fc55a> in <module>()
# ----> 1 foo = dat.Income[dat.Region == bb[i]]
#       2 len(foo)
#       3 be[bb[i]] = foo
#       4
#       5 i = i + 1
#
# IndexError: index out of bounds

# %%
#dat.Income[dat.Region == bb[i]]
i = 0

# %%
bb = np.unique(d2)
i = bb[0]
foo = dat.Income[dat.Region == i]

#incoYR[np.isfinite(incoYR.loc[:,year])]
foo
# Out:
# 0      6300.648214
# 1      5497.618103
# 2      1438.986214
# 3     13181.342015
# 4       468.432182
# 5      2017.815915
# 6      3655.839336
# 7      1759.973441
# 8      1022.624550
# 9      2165.763841
# 10     6059.975994
# 11    13383.763401
# 12      561.050007
# 13      871.837116
# 14    12542.546029
# 15      793.618434
# 16     1485.657586
# 17      939.371879
# 18      595.536860
# 19     1471.325641
# 20     1801.349543
# 21      450.117363
# 22    11842.386096
# 23      995.218487
# 24      844.422690
# 25     1121.551629
# 26     1801.646396
# 27    12317.235587
# 28     4263.175989
# 29      954.487556
# 30     5159.794219
# 31      661.177130
# 32     2297.341367
# 33     1094.057911
# 34     1835.456105
# 35     1740.515097
# 36    16341.864978
# 37      889.581839
# 38      948.484363
# 39     9322.168814
# 40     2709.001354
# 41     2597.127808
# 42     5163.288425
# 43     1229.299421
# 44      925.390085
# 45     7664.840299
# 46     1219.457289
# 47     1420.231814
# 48      479.824780
# Name: Income, dtype: float64

# %%
#ds2=dat[['Region', "Income"]]
#ds3=ds2.set_index('Region')

#ds3.boxplot(ds3, by = "Region")
#plt.title('xxxxxxxxxxxxxx', fontsize = 10)

# %%
import pylab as py

# fake up some data
spread= py.rand(50) * 100


data = spread



# fake up some more data
spread= py.rand(50) * 100
d2 = spread
#data.shape = (-1, 1)
#d2.shape = (-1, 1)
#data = concatenate( (data, d2), 1 )
# Making a 2-D array only works if all the columns are the
# same length.  If they are not, then use a list instead.
# This is actually more efficient because boxplot converts
# a 2-D array into a list of vectors internally anyway.
data = [data, d2]
# multiple box plots on one figure
py.figure()
py.boxplot(data)

py.show()
list(data)
# Out:
# [array([ 81.06576436,  91.89166966,  93.36513737,  42.36365387,
#          85.10085522,  21.92774908,  70.61166442,  96.81618385,
#          80.06857365,  97.62125202,  21.86076329,  62.08084772,
#          24.0584945 ,  39.40239611,  75.28914817,  88.87427809,
#          56.81267494,  88.83693724,  22.30249618,  45.59010972,
#          15.55904378,  36.07836538,  53.51121482,  82.30469526,
#          73.85718884,  70.97148507,  21.75714547,   5.52607404,
#           7.38206767,  53.57735502,   9.57971396,  22.50066714,
#           2.78896285,  20.35946089,  43.36049241,  11.99772678,
#          28.93473742,  27.82450825,  16.63570495,  45.42158076,
#          71.33908336,   2.55427058,  18.61939586,  95.7455524 ,
#           3.8548366 ,  28.06226883,  27.90647458,  36.57574311,
#          65.06438202,  28.49485014]),
#  array([ 96.47211603,  44.27323799,  19.89152931,  59.84015223,
#          40.18966098,   0.58001053,  34.68582504,  38.49748748,
#          63.18137143,  71.53158027,  63.23886316,   9.8188513 ,
#          42.53895866,  70.31875206,  23.95586709,  47.59693516,
#          66.76920912,  77.80196804,  90.00648592,  17.57130503,
#          56.90695787,  75.02014441,  52.54894515,  59.19327771,
#          37.16163214,  48.98406264,  18.18465829,  54.81529944,
#          92.88924327,  49.76663613,  75.41898089,  18.95137299,
#          95.12512616,  40.3067225 ,   2.84623628,  51.8378033 ,
#          36.51852894,  31.54270311,  62.8652787 ,  64.16544367,
#          44.49398081,  16.84793073,  57.80477832,  79.09627972,
#          36.78759034,  21.29143374,  19.23998996,   8.07354542,
#          62.83399568,  23.72889148])]

# %% [markdown]
# ## Discussion for Problem 2
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---

# %% [markdown]
# ## Problem 3
#
# In general, if group A has larger values than group B on average, does this mean the largest values are from group A? Discuss after completing each of the problems below.

# %% [markdown]
# #### Problem 3(a)
#
# Assume you have two list of numbers, X and Y, with distribution approximately normal. X and Y have standard deviation equal to 1, but the average of X is different from the average of Y.  If the difference in the average of X and the average of Y is larger than 0, how does the proportion of X > a compare to the proportion of Y > a?

# %% [markdown]
# Write a function that analytically calculates the ratio of these two proportions: Pr(X > a)/Pr(Y > a) as function of the difference in the average of X and the average of Y.
#
# **Hint**: Use the `scipy.stats` module for useful functions related to a normal random variable such as the probability density function, cumulative distribution function and survival function.
#
# **Update**: Assume Y is normally distributed with mean equal to 0.

# %%
"""
Function
--------
ratioNormals

Return ratio of these two proportions: 
    Pr(X > a)/Pr(Y > a) as function of 
    the difference in the average of X 
    and the average of Y. 

Parameters
----------
diff : difference in the average of X 
    and the average of Y. 
a : cutoff value

Returns
-------
Returns ratio of these two proportions: 
    Pr(X > a)/Pr(Y > a)
    
Example
-------
>>> ratioNormals(diff = 1, a = 2)
"""
#your code here

# %% [markdown]
# Show the curve for different values of a (a = 2,3,4 and 5).

# %%
#your code here

# %% [markdown]
# #### Problem 3(b)
#
# Now consider the distribution of income per person from two regions: Asia and South America. Estimate the average income per person across the countries in those two regions. Which region has the larger average of income per person across the countries in that region?
#
# **Update**: Use the year 2012.

# %%
#your code here

# %% [markdown]
# #### Problem 3(c)
#
# Calculate the proportion of countries with income per person that is greater than 10,000 dollars. Which region has a larger proportion of countries with income per person greater than 10,000 dollars? If the answer here is different from the answer in 3(b), explain why in light of your answer to 3(a).
#
# **Update**: Use the year 2012.

# %%
#your code here

# %% [markdown]
# #### Problem 3(d)
#
# **For AC209 Students**: Re-run this analysis in Problem 3 but compute the average income per person for each region, instead of the average of the reported incomes per person across countries in the region. Why are these two different? Hint: use this [data set](https://spreadsheets.google.com/pub?key=phAwcNAVuyj0XOoBL_n5tAQ&gid=0).

# %%
#your code here

# %% [markdown]
# ## Discussion for Problem 3
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---
