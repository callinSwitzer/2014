# %% [markdown]
# # Homework 3: Prediction and Classification
#
# Due: Thursday, October 16, 2014 11:59 PM
#
# <a href=https://raw.githubusercontent.com/cs109/2014/master/homework/HW3.ipynb download=HW3.ipynb> Download this assignment</a>
#
# #### Submission Instructions
# To submit your homework, create a folder named lastname_firstinitial_hw# and place your IPython notebooks, data files, and any other files in this folder. Your IPython Notebooks should be completely executed with the results visible in the notebook. We should not have to run any code. Compress the folder (please use .zip compression) and submit to the CS109 dropbox in the appropriate folder. If we cannot access your work because these directions are not followed correctly, we will not grade your work.
#
# ---

# %% [markdown]
# # Introduction
#
# In this assignment you will be using regression and classification to explore different data sets.
#
# **First**: You will use data from before 2002 in the [Sean Lahman's Baseball Database](http://seanlahman.com/baseball-archive/statistics) to create a metric for picking baseball players using linear regression. This is same database we used in Homework 1. This database contains the "complete batting and pitching statistics from 1871 to 2013, plus fielding statistics, standings, team stats, managerial records, post-season data, and more". [Documentation provided here](http://seanlahman.com/files/database/readme2012.txt).
#
# !["Sabermetrics Science"](http://saberseminar.com/wp-content/uploads/2012/01/saber-web.jpg)
# http://saberseminar.com/wp-content/uploads/2012/01/saber-web.jpg
#
# **Second**: You will use the famous [iris](http://en.wikipedia.org/wiki/Iris_flower_data_set) data set to perform a $k$-neareast neighbor classification using cross validation.  While it was introduced in 1936, it is still [one of the most popular](http://archive.ics.uci.edu/ml/) example data sets in the machine learning community. Wikipedia describes the data set as follows: "The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimetres." Here is an illustration what the four features measure:
#
# !["iris data features"](http://sebastianraschka.com/Images/2014_python_lda/iris_petal_sepal.png)
# http://sebastianraschka.com/Images/2014_python_lda/iris_petal_sepal.png
#
# **Third**: You will investigate the influence of higher dimensional spaces on the classification using another standard data set in machine learning called the The [digits data set](http://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_digits.html).  This data set is similar to the MNIST data set discussed in the lecture. The main difference is, that each digit is represented by an 8x8 pixel image patch, which is considerably smaller than the 28x28 pixels from MNIST. In addition, the gray values are restricted to 16 different values (4 bit), instead of 256 (8 bit) for MNIST.
#
# **Finally**: In preparation for Homework 4, we want you to read through the following articles related to predicting the 2014 Senate Midterm Elections.
#
# * [Nate Silver's Methodology at while at NYT](http://fivethirtyeight.blogs.nytimes.com/methodology/)
# * [How The FiveThirtyEight Senate Forecast Model Works](http://fivethirtyeight.com/features/how-the-fivethirtyeight-senate-forecast-model-works/)
# * [Pollster Ratings v4.0: Methodology](http://fivethirtyeight.com/features/pollster-ratings-v40-methodology/)
# * [Pollster Ratings v4.0: Results](http://fivethirtyeight.com/features/pollster-ratings-v40-results/)
# * [Nate Silver versus Sam Wang](http://www.washingtonpost.com/blogs/plum-line/wp/2014/09/17/nate-silver-versus-sam-wang/)
# * [More Nate Silver versus Sam Wang](http://www.dailykos.com/story/2014/09/09/1328288/-Get-Ready-To-Rumbllllle-Battle-Of-The-Nerds-Nate-Silver-VS-Sam-Wang)
# * [Nate Silver explains critisims of Sam Wang](http://politicalwire.com/archives/2014/10/02/nate_silver_rebuts_sam_wang.html)
# * [Background on the feud between Nate Silver and Sam Wang](http://talkingpointsmemo.com/dc/nate-silver-sam-wang-feud)
# * [Are there swing voters?]( http://www.stat.columbia.edu/~gelman/research/unpublished/swing_voters.pdf)
#
#
#
# ---

# %% [markdown]
# ## Load Python modules

# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

import requests 
import StringIO
import zipfile
import numpy as np
import pandas as pd # pandas
from mpl_toolkits.axes_grid.axislines import Subplot
import matplotlib.pyplot as plt # module for plotting 
import scipy
import scipy as sp
from statsmodels.nonparametric.smoothers_lowess import lowess
import statsmodels.api as sm
import random
import math


# If this module is not already installed, you may need to install it. 
# You can do this by typing 'pip install seaborn' in the command line
import seaborn as sns 
from sklearn.cross_validation import KFold

import sklearn
import sklearn.datasets
import sklearn.cross_validation
import sklearn.decomposition
import sklearn.grid_search
import sklearn.neighbors
import sklearn.metrics
from mpl_toolkits.axes_grid.axislines import Subplot

from __future__ import print_function
from sklearn.grid_search import GridSearchCV

# %% [markdown]
# # Problem 1: Sabermetrics
#
# Using data preceding the 2002 season pick 10 offensive players keeping the payroll under $20 million (assign each player the median salary). Predict how many games this team would win in a 162 game season.
#
# In this problem we will be returning to the [Sean Lahman's Baseball Database](http://seanlahman.com/baseball-archive/statistics) that we used in Homework 1.  From this database, we will be extract five data sets containing information such as yearly stats and standing, batting statistics, fielding statistics, player names, player salaries and biographical information. You will explore the data in this database from before 2002 and create a metric for picking players.

# %% [markdown]
# #### Problem 1(a)
#
# Load in [these CSV files](http://seanlahman.com/files/database/lahman-csv_2014-02-14.zip) from the [Sean Lahman's Baseball Database](http://seanlahman.com/baseball-archive/statistics). For this assignment, we will use the 'Teams.csv', 'Batting.csv', 'Salaries.csv', 'Fielding.csv', 'Master.csv' tables. Read these tables into separate pandas DataFrames with the following names.
#
# CSV file name | Name of pandas DataFrame
# :---: | :---:
# Teams.csv | teams
# Batting.csv | players
# Salaries.csv | salaries
# Fielding.csv | fielding
# Master.csv | master

# %%
### Your code here ###
r = requests.get("http://seanlahman.com/files/database/lahman-csv_2014-02-14.zip")
z = zipfile.ZipFile(StringIO.StringIO(r.content))
z.extractall("data")
teams = pd.read_csv("data/Teams.csv")
players = pd.read_csv("data/Batting.csv")
salaries = pd.read_csv("data/Salaries.csv")
fielding = pd.read_csv("data/Fielding.csv")
master = pd.read_csv("data/Master.csv")

# %% [markdown]
# #### Problem 1(b)
#
# Calculate the median salary for each player and create a pandas DataFrame called `medianSalaries` with four columns: (1) the player ID, (2) the first name of the player, (3) the last name of the player and (4) the median salary of the player. Show the head of the `medianSalaries` DataFrame.

# %%
### Your code here ###
grouped = salaries.groupby('playerID', as_index = False)
salary_med = grouped.median()
salary_med.columns = ["playerID", "yearID", "medianSalaries"]
medSal = pd.merge(salary_med, master)
medianSalaries = medSal[["playerID","nameFirst", "nameLast", "medianSalaries"]]
medianSalaries.head()
# Out:
#     playerID nameFirst nameLast  medianSalaries
# 0  aardsda01     David  Aardsma          419000
# 1   aasedo01       Don     Aase          612500
# 2   abadan01      Andy     Abad          327000
# 3   abadfe01  Fernando     Abad          451500
# 4  abbotje01      Jeff   Abbott          255000

# %% [markdown]
# #### Problem 1(c)
#
# Now, consider only team/season combinations in which the teams played 162 Games. Exclude all data from before 1947. Compute the per plate appearance rates for singles, doubles, triples, HR, and BB. Create a new pandas DataFrame called `stats` that has the teamID, yearID, wins and these rates.
#
# **Hint**: Singles are hits that are not doubles, triples, nor HR. Plate appearances are base on balls plus at bats.

# %%
### Your code here ###
t1 = teams.loc[teams.yearID > 1947,]
t2 = t1.loc[t1.G == 162,]
stat1 = t2[["teamID", "yearID","W", "AB", "H","2B","3B", "HR", "BB"]]
stat1["1BRate"] = (stat1["H"] - stat1["2B"]- stat1["3B"]- stat1["HR"])/ (stat1.AB + stat1.BB)
stat1["2BRate"] = stat1["2B"]/(stat1.AB + stat1.BB)
stat1["3BRate"] = stat1["3B"]/(stat1.AB + stat1.BB)
stat1["HRRate"] = stat1["HR"] / (stat1.AB + stat1.BB)
stat1["BBRate"] = stat1["BB"] / (stat1.AB + stat1.BB)

stats = stat1[["teamID", "yearID", "W", "1BRate", "2BRate", "3BRate", "HRRate", "BBRate"]]
stats.head()
# Out:
#      teamID  yearID   W    1BRate    2BRate    3BRate    HRRate    BBRate
# 1366    LAA    1961  70  0.147748  0.035708  0.003604  0.030958  0.111548
# 1367    KC1    1961  61  0.164751  0.035982  0.007829  0.014993  0.096618
# 1377    NYA    1962  96  0.167148  0.038536  0.004656  0.031952  0.093770
# 1379    LAA    1962  86  0.159482  0.038027  0.005737  0.022455  0.098672
# 1381    CHA    1962  85  0.165797  0.040756  0.009129  0.014998  0.101076

# %% [markdown]
# #### Problem 1(d)
#
# Is there a noticeable time trend in the rates computed computed in Problem 1(c)?
#
# _____________
# Answer: Yes.  The plots below show a noticeable time trend for singles, doubles, and home runs.  Doubles and home runs had a big increase during the years ~ 1995 - 2005, then they started decreasing. Triples and base on balls didn't change very much.  Singles decreased as doubles and home runs increased.

# %%
sns.set_style("ticks")
names = ["Singles", "Doubles", "Triples", "Home Runs", "Base on Balls"]
ctr = 0
for i in ["1BRate", "2BRate", "3BRate", "HRRate", "BBRate"]:
    x = stats.yearID
    y = stats[i]

    #f = interp1d(x, y, 'zero')
    L = lowess(y, x, frac=1./3)

    #set figure and axis
    fig = plt.figure(figsize=(6, 4))
    ax = Subplot(fig, 111)
    fig.add_subplot(ax)

    #plot
    ax.scatter(x, y, s=20, facecolor='0', alpha = 0.5, lw = 0) 
    plt.xlabel("Year") # xlabel
    plt.ylabel("Rate") # ylabel
    plt.title("Year vs " + names[ctr] + " Rate") # title
    plt.xlim(1960, 2014)

    #do not display top and right axes
    ax.axis["right"].set_visible(False)
    ax.axis["top"].set_visible(False)
    ax.plot(L[:,0], L[:,1], '-', lw=4, color='orange', label = "Lowess smoothing line")
    plt.legend(loc = 3)
    plt.show()
    ctr = ctr + 1

# %% [markdown]
# #### Problem 1(e)
#
# Using the `stats` DataFrame from Problem 1(c), adjust the singles per PA rates so that the average across teams for each year is 0. Do the same for the doubles, triples, HR, and BB rates.

# %%
### Your code here ###
stats["1BRate"].mean()
grouped = stats.groupby('yearID', as_index = False)
yearlyMean = grouped.mean()
yearlyMean.head()
# Out:
#    yearID          W    1BRate    2BRate    3BRate    HRRate    BBRate
# 0    1961  65.500000  0.156249  0.035845  0.005717  0.022975  0.104083
# 1    1962  78.454545  0.165632  0.035853  0.006777  0.023811  0.088590
# 2    1963  78.142857  0.162467  0.034020  0.006896  0.021254  0.080336
# 3    1964  81.727273  0.167251  0.036336  0.006748  0.021548  0.079152
# 4    1965  82.000000  0.160042  0.035539  0.006534  0.022693  0.085745

# %%
#i = 1961
#j = "1BRate"
#smS = statsC.loc[statsC.yearID == i]
#yearlyMean[j][yearlyMean.yearID == i]

#smS[j] - float(yearlyMean[j][yearlyMean.yearID == i])
#float(mean)

# %%
stat3 = stats.copy()
statsC = stats.copy()
for i in yearlyMean.yearID:
    smS = statsC.loc[statsC.yearID == i].copy()
    for j in ["1BRate", "2BRate", "3BRate", "HRRate", "BBRate"]:
        smS[j] = smS[j] - float(yearlyMean[j][yearlyMean.yearID == i])
    stat3.loc[stat3.yearID == i] = smS.copy()
stat3.head()
# Out:
#      teamID  yearID   W    1BRate    2BRate    3BRate    HRRate    BBRate
# 1366    LAA    1961  70 -0.008502 -0.000137 -0.002113  0.007983  0.007465
# 1367    KC1    1961  61  0.008502  0.000137  0.002113 -0.007983 -0.007465
# 1377    NYA    1962  96  0.001516  0.002683 -0.002121  0.008141  0.005180
# 1379    LAA    1962  86 -0.006150  0.002174 -0.001040 -0.001356  0.010082
# 1381    CHA    1962  85  0.000165  0.004904  0.002352 -0.008813  0.012486

# %% [markdown]
# #### Problem 1(f)
#
# Build a simple linear regression model to predict the number of wins from the average adjusted singles, double, triples, HR, and BB rates. To decide which of these terms to include fit the model to data from 2002 and compute the average squared residuals from predictions to years past 2012. Use the fitted model to define a new sabermetric summary: offensive predicted wins (OPW). Hint: the new summary should be a linear combination of one to five of the five rates.

# %%
### Your code here ###
## 2002
best = [None]*6

for ww in range(6):
    
    max1 = [None] * 100
    numToSample = ww
    items = ["1BRate", "2BRate", "3BRate", "HRRate", "BBRate"]
    

    for hh in range(len(max1)):
        items1 = random.sample(items, numToSample)
        s2002 = stat3.loc[stat3.yearID == 2002]
        X = s2002[items1]
        y = s2002['W']

        ## fit a OLS model with intercept on "1BRate", "2BRate", "3BRate", "HRRate", "BBRate"
        X = sm.add_constant(X)
        est = sm.OLS(y, X).fit()
        res = [None]*len(range(2003, 2013))
        ctr = 0
        for w in range(2003, 2013):
            Y = stat3.loc[stat3.yearID == w][items1]
            Y = sm.add_constant(Y)
            Y["predictWin"] = est.predict(Y) # this is Offensive predicted wins
            Y["actualWin"] = stat3.loc[stat3.yearID == w]["W"]
            res[ctr] = sum((Y.actualWin - Y.predictWin)**2)/len(Y.actualWin)
            ctr = ctr + 1
        max1[hh] = (np.array(res).sum(), items1)
    mm = pd.DataFrame(max1)
    ff = mm.loc[mm[0] == mm[0].min()]
    #print((ff.iloc[0], max1[0]))
    best[ww] = (ff.iloc[0])

bb = pd.DataFrame(best)
bb.columns = ["residuals", "Predictors"]
bb
# Out:
#       residuals                                Predictors
# 0   1277.045907                                        []
# 2   1076.477580                                  [BBRate]
# 7    984.296674                          [HRRate, BBRate]
# 60   982.919535                  [3BRate, BBRate, HRRate]
# 25  1157.548082          [HRRate, 2BRate, BBRate, 1BRate]
# 44  1330.679952  [HRRate, 3BRate, 1BRate, 2BRate, BBRate]

# %%
items = ["BBRate","3BRate", "HRRate"] # maybe BBRate

ss = stat3#.loc[stat3.yearID == 2002]
X = ss[items]
y = ss['W']

## fit a OLS model with intercept on "1BRate", "2BRate", "3BRate", "HRRate", "BBRate"
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      W   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.236
# Method:                 Least Squares   F-statistic:                     102.3
# Date:                Tue, 14 Oct 2014   Prob (F-statistic):           1.26e-57
# Time:                        23:02:15   Log-Likelihood:                -3650.0
# No. Observations:                 984   AIC:                             7308.
# Df Residuals:                     980   BIC:                             7328.
# Df Model:                           3
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const         81.0528      0.316    256.850      0.000        80.434    81.672
# BBRate       385.5836     34.151     11.291      0.000       318.567   452.601
# 3BRate      1405.0240    210.697      6.668      0.000       991.555  1818.493
# HRRate       726.6614     69.582     10.443      0.000       590.115   863.208
# ==============================================================================
# Omnibus:                        1.818   Durbin-Watson:                   1.869
# Prob(Omnibus):                  0.403   Jarque-Bera (JB):                1.891
# Skew:                          -0.090   Prob(JB):                        0.389
# Kurtosis:                       2.882   Cond. No.                         669.
# ==============================================================================
# """

# %% [markdown]
# ** Your answer here: **
#
# I fit a models for every linear combination of rates -- Singles, Doubles, Triples, Home Runs, and Base on Balls -- for the year 2002.  Then I used those models to predict the next years wins, through 2012. I calculated the squared residuals by taking the (predicted wins - actual wins)^2 for each year after 2002.  The linear combination that gave the smallest sum of squared residuals was this model:  Wins = B1 + B2*(Base on balls rate) + B3*(Triple rate) + B4*(Home run rate) + random error.
#
# From the multiple regression above, the coefficients would look like this:
# Wins = 81.06 + 385.58*(Base on balls rate) + 1405.02*(Triple rate) + 726.66*(Home run rate) + random error.

# %% [markdown]
# #### Problem 1(g)
#
# Now we will create a similar database for individual players. Consider only player/year combinations in which the player had at least 500 plate appearances. Consider only the years we considered for the calculations above (after 1947 and seasons with 162 games). For each player/year compute singles, doubles, triples, HR, BB per plate appearance rates. Create a new pandas DataFrame called `playerstats` that has the playerID, yearID and the rates of these stats.  Remove the avareage for each year as for these rates as done in Problem 1(e).

# %%
### Your code here ###
#pd.set_option('display.height', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 200)
yearsWant = yearlyMean.yearID ## these are the years we want
players1 = players.loc[players.yearID.isin(yearsWant)]# cut data frame to only the years I want

## get total plate appearances for players
grouped = players1.groupby('playerID', as_index = False)
playerSums = grouped.sum()
playerSums.head()

## filter to players who have had more than 500 at-bats
player500 = playerSums.loc[(playerSums.AB + playerSums.BB) >= 500] # I'm ignoring sac bunts
playersWant = player500.playerID  #players who have had more than 500 at-bats


## filter players1 to only the players that I want
players2 = players1.loc[players1.playerID.isin(playersWant)]

## compute rates per plate appearance
players2["PlateAppearances"] = players2.AB + players2.BB
players2["2BRate"] = players["2B"] / (players2.PlateAppearances)
players2["3BRate"] = players["3B"] / (players2.PlateAppearances)
players2["BBRate"] = players["BB"] / (players2.PlateAppearances)
players2["HRRate"] = players["HR"] / (players2.PlateAppearances)
players2["1BRate"] = (players["H"] -players["2B"]- players["3B"]-players["HR"]) / (players2.PlateAppearances)
players3 = players2[["playerID", "yearID", "1BRate", "2BRate", "3BRate", "HRRate", "BBRate"]]

## compute yearly averages
grouped = players3.groupby('yearID', as_index = False)
yearM = grouped.mean()

## subtract yearly averages
players4 = players3.copy()
playerstats = players3.copy()
for i in yearsWant:
    smS = players4.loc[players4.yearID == i].copy()
    for j in ["1BRate", "2BRate", "3BRate", "HRRate", "BBRate"]:
        smS[j] = smS[j] - float(yearM[j][yearM.yearID == i])
    playerstats.loc[playerstats.yearID == i] = smS.copy()

# %% [markdown]
# Show the head of the `playerstats` DataFrame.

# %%
## show head    
playerstats.head()
# Out:
#      playerID  yearID    1BRate    2BRate    3BRate    HRRate    BBRate
# 14  aaronha01    1961  0.014725  0.024578  0.009290  0.029636 -0.002677
# 15  aaronha01    1962  0.011690  0.009840  0.003150  0.047163  0.010658
# 16  aaronha01    1963  0.021360  0.010610  0.000042  0.042754  0.033302
# 17  aaronha01    1964  0.052759  0.018107 -0.002250  0.020025  0.020173
# 18  aaronha01    1965  0.020164  0.032741 -0.003883  0.031621  0.019088

# %% [markdown]
# #### Problem 1(h)
#
# Using the `playerstats` DataFrame created in Problem 1(g), create a new DataFrame called `playerLS` containing the player's lifetime stats. This DataFrame should contain the playerID, the year the player's career started, the year the player's career ended and the player's lifetime average for each of the quantities (singles, doubles, triples, HR, BB). For simplicity we will simply compute the avaerage of the rates by year (a more correct way is to go back to the totals).

# %%
### Your code here ###
grouped = playerstats.groupby('playerID', as_index = False)
life = grouped.mean()
minL = grouped.min()
maxL = grouped.max()
startYear = minL.yearID # starting year for each player
endYear = maxL.yearID # year the player's career ended
life["startYear"] = startYear
life["endYear"] = endYear
playerLS = life[["playerID", "startYear", "endYear", "1BRate", "2BRate", "3BRate", "HRRate", "BBRate"]]

# %% [markdown]
# Show the head of the `playerLS` DataFrame.

# %%
### Your code here ###
playerLS.head()
# Out:
#     playerID  startYear  endYear    1BRate    2BRate    3BRate    HRRate    BBRate
# 0  aaronha01       1961     1976  0.003238  0.011611 -0.001205  0.039541  0.029938
# 1  aaronto01       1962     1971  0.004776  0.001152 -0.002123 -0.006921 -0.010133
# 2  abbotje01       1997     2001  0.010147 -0.001040 -0.003049 -0.000812 -0.031521
# 3  abbotku01       1993     2001  0.002488  0.002714  0.001301  0.002411 -0.035760
# 4  abernbr01       2001     2005 -0.026965 -0.024974 -0.002460 -0.017081 -0.027894

# %% [markdown]
# #### Problem 1(i)
#
# Compute the OPW for each player based on the average rates in the playerLS DataFrame. You can interpret this summary statistic as the predicted wins for a team with 9 batters exactly like the player in question. Add this column to the playerLS DataFrame. Call this colum OPW.

# %%
### Your code here ###
items = ["BBRate","3BRate", "HRRate"] # the best predictors from my model above
Y = playerLS[items]#loc[playerLS.yearID == w][items1]
Y = sm.add_constant(Y)
Y["OPW"] = est.predict(Y) # this is Offensive predicted wins

playerLS["OPW"] = Y.OPW
playerLS.head()
# Out:
#     playerID  startYear  endYear    1BRate    2BRate    3BRate    HRRate    BBRate         OPW
# 0  aaronha01       1961     1976  0.003238  0.011611 -0.001205  0.039541  0.029938  119.635453
# 1  aaronto01       1962     1971  0.004776  0.001152 -0.002123 -0.006921 -0.010133   69.133891
# 2  abbotje01       1997     2001  0.010147 -0.001040 -0.003049 -0.000812 -0.031521   64.025461
# 3  abbotku01       1993     2001  0.002488  0.002714  0.001301  0.002411 -0.035760   70.844877
# 4  abernbr01       2001     2005 -0.026965 -0.024974 -0.002460 -0.017081 -0.027894   54.429261

# %% [markdown]
# #### Problem 1(j)
#
# Add four columns to the `playerLS` DataFrame that contains the player's position (C, 1B, 2B, 3B, SS, LF, CF, RF, or OF), first name, last name and median salary.

# %%
playerPos = fielding[["playerID", "POS"]]
playerPos # player positions
medianSalaries
#playerNames = master[["playerID", "nameFirst", "nameLast"]]
#playerNames # players' first and last names 

posSal = pd.merge(medianSalaries, playerPos, how = "outer" )
posSal = posSal.drop_duplicates()
#posSal.loc[posSal.playerID == "aaronha01"]

tot = pd.merge(playerLS, posSal)

## get rid of players for whom we don't have median salary 
play = tot[~(np.isnan(tot.medianSalaries))]

# %% [markdown]
# Show the head of the `playerLS` DataFrame.

# %%
### Your code here ###
playerLS = play.copy()
playerLS.head()
# Out:
#      playerID  startYear  endYear    1BRate   2BRate    3BRate    HRRate    BBRate        OPW nameFirst nameLast  medianSalaries POS
# 15  abbotje01       1997     2001  0.010147 -0.00104 -0.003049 -0.000812 -0.031521  64.025461      Jeff   Abbott          255000  CF
# 16  abbotje01       1997     2001  0.010147 -0.00104 -0.003049 -0.000812 -0.031521  64.025461      Jeff   Abbott          255000  DH
# 17  abbotje01       1997     2001  0.010147 -0.00104 -0.003049 -0.000812 -0.031521  64.025461      Jeff   Abbott          255000  LF
# 18  abbotje01       1997     2001  0.010147 -0.00104 -0.003049 -0.000812 -0.031521  64.025461      Jeff   Abbott          255000  OF
# 19  abbotje01       1997     2001  0.010147 -0.00104 -0.003049 -0.000812 -0.031521  64.025461      Jeff   Abbott          255000  RF

# %% [markdown]
# #### Problem 1(k)
#
# Subset the `playerLS` DataFrame for players active in 2002 and 2003 and played at least three years. Plot and describe the relationship bewteen the median salary (in millions) and the predicted number of wins.

# %%
# calculate average for each person, regardless of their position
grouped = playerLS.groupby('playerID', as_index = False)
sal = grouped.mean()
sal.medianSalaries = sal.medianSalaries / 1000000

sal1 = sal[(sal.startYear <= 2002) & (sal.endYear >= 2003) & ((sal.endYear - sal.startYear) >= 3)]
sal1.head()
# Out:
#      playerID  startYear  endYear    1BRate    2BRate    3BRate    HRRate    BBRate         OPW  medianSalaries
# 2   abernbr01       2001     2005 -0.026965 -0.024974 -0.002460 -0.017081 -0.027894   54.429261          0.2575
# 4   abreubo01       1996     2012 -0.000646  0.013986  0.000564  0.000859  0.057459  104.625422          9.0000
# 11  alexama02       1992     2006 -0.011883 -0.006847  0.003907 -0.017709 -0.029344   62.358459          0.1975
# 12  alfoned01       1996     2006  0.013532 -0.001779 -0.002593 -0.004180  0.013439   79.555068          4.1125
# 16  allench01       1999     2005 -0.000041  0.011356  0.008681 -0.018847 -0.041367   63.604364          0.2400

# %%
# plot a scatterplot
x = sal1.medianSalaries
y = sal1.OPW

#f = interp1d(x, y, 'zero')
L = lowess(y, x, frac=1./3)

#set figure and axis
fig = plt.figure(figsize=(6, 4))
ax = Subplot(fig, 111)
fig.add_subplot(ax)

#plot
ax.scatter(x, y, s=20, facecolor='0', alpha = 0.2, lw = 0) 
plt.xlabel("Salaries (million $)") # xlabel
plt.ylabel("Predicted Number of wins") # ylabel
plt.title("Salaries vs predicted number of wins") # title
plt.xlim(0, 25)

#do not display top and right axes
ax.axis["right"].set_visible(False)
ax.axis["top"].set_visible(False)
ax.plot(L[:,0], L[:,1], '-', lw=2, color='red', label = "Lowess smoothing line")
plt.legend(loc = 1)

plt.show()

# %% [markdown]
# #### Problem 1(l)
# Pick one players from one of each of these 10 position C, 1B, 2B, 3B, SS, LF, CF, RF, DH, or OF keeping the total median salary of all 10 players below 20 million. Report their averaged predicted wins and total salary.

# %%
# view a plot
# plot a scatterplot
sal1 = sal1.reset_index(drop=True)
x = sal1.medianSalaries
y = sal1.OPW

#f = interp1d(x, y, 'zero')
L = lowess(y, x, frac=1./3)

#set figure and axis
fig = plt.figure(figsize=(15, 5))
ax = Subplot(fig, 111)
fig.add_subplot(ax)

#plot
ax.scatter(x, y, s=20, facecolor='0', alpha = 0.2, lw = 0) 
plt.xlabel("Salaries (million $)") # xlabel
plt.ylabel("Predicted Number of wins") # ylabel
plt.title("Salaries vs predicted number of wins") # title
plt.xlim(0, 5)
plt.ylim(100, 140)

#do not display top and right axes
ax.axis["right"].set_visible(False)
ax.axis["top"].set_visible(False)
#ax.plot(L[:,0], L[:,1], '-', lw=2, color='red', label = "Lowess smoothing line")
#plt.legend(loc = 1)
for i, txt in enumerate(sal1.playerID):
    ax.annotate(txt, (x[i],y[i]))
plt.show()

# %%
pd.set_option('display.max_rows', 1200)
pd.set_option('display.max_columns', 1200)
myTeam1 = sal1.loc[sal1.OPW > 100,]
myTeam = myTeam1.loc[myTeam1.medianSalaries < 5,]

mt = pd.merge(playerPos, myTeam)

#mt.sort("OPW", ascending = False)

playerNames = master[["playerID", "nameFirst", "nameLast"]]
playerNames # players' first and last names 

mt1 = pd.merge(playerNames, mt)
mt1 = mt1.sort("OPW", ascending = False)
mt1[mt1.POS == "OF"]
# Out:
#        playerID nameFirst   nameLast POS  startYear  endYear    1BRate    2BRate    3BRate    HRRate    BBRate         OPW  medianSalaries
# 1016   riosar01   Armando       Rios  OF       1998     2003  0.017385 -0.010822 -0.000768  0.024351  0.083089  129.705775        0.310000
# 1012   riosar01   Armando       Rios  OF       1998     2003  0.017385 -0.010822 -0.000768  0.024351  0.083089  129.705775        0.310000
# 1008   riosar01   Armando       Rios  OF       1998     2003  0.017385 -0.010822 -0.000768  0.024351  0.083089  129.705775        0.310000
# 1020   riosar01   Armando       Rios  OF       1998     2003  0.017385 -0.010822 -0.000768  0.024351  0.083089  129.705775        0.310000
# 1021   riosar01   Armando       Rios  OF       1998     2003  0.017385 -0.010822 -0.000768  0.024351  0.083089  129.705775        0.310000
# 1025   riosar01   Armando       Rios  OF       1998     2003  0.017385 -0.010822 -0.000768  0.024351  0.083089  129.705775        0.310000
# 1030   riosar01   Armando       Rios  OF       1998     2003  0.017385 -0.010822 -0.000768  0.024351  0.083089  129.705775        0.310000
# 510   giambja01     Jason     Giambi  OF       1996     2013 -0.025094 -0.000428 -0.003872  0.026118  0.075882  123.850785        3.103333
# 505   giambja01     Jason     Giambi  OF       1996     2013 -0.025094 -0.000428 -0.003872  0.026118  0.075882  123.850785        3.103333
# 966   pridecu01    Curtis      Pride  OF       1993     2006 -0.049817  0.006043  0.010724  0.049465 -0.024976  122.434454        0.183000
# 980   pridecu01    Curtis      Pride  OF       1993     2006 -0.049817  0.006043  0.010724  0.049465 -0.024976  122.434454        0.183000
# 969   pridecu01    Curtis      Pride  OF       1993     2006 -0.049817  0.006043  0.010724  0.049465 -0.024976  122.434454        0.183000
# 1004  pridecu01    Curtis      Pride  OF       1993     2006 -0.049817  0.006043  0.010724  0.049465 -0.024976  122.434454        0.183000
# 1001  pridecu01    Curtis      Pride  OF       1993     2006 -0.049817  0.006043  0.010724  0.049465 -0.024976  122.434454        0.183000
# 997   pridecu01    Curtis      Pride  OF       1993     2006 -0.049817  0.006043  0.010724  0.049465 -0.024976  122.434454        0.183000
# 992   pridecu01    Curtis      Pride  OF       1993     2006 -0.049817  0.006043  0.010724  0.049465 -0.024976  122.434454        0.183000
# 989   pridecu01    Curtis      Pride  OF       1993     2006 -0.049817  0.006043  0.010724  0.049465 -0.024976  122.434454        0.183000
# 985   pridecu01    Curtis      Pride  OF       1993     2006 -0.049817  0.006043  0.010724  0.049465 -0.024976  122.434454        0.183000
# 972   pridecu01    Curtis      Pride  OF       1993     2006 -0.049817  0.006043  0.010724  0.049465 -0.024976  122.434454        0.183000
# 976   pridecu01    Curtis      Pride  OF       1993     2006 -0.049817  0.006043  0.010724  0.049465 -0.024976  122.434454        0.183000
# 1299  vaughgr01      Greg     Vaughn  OF       1989     2003 -0.046351 -0.002875 -0.001613  0.029524  0.043264  116.922610        4.437500
# 1295  vaughgr01      Greg     Vaughn  OF       1989     2003 -0.046351 -0.002875 -0.001613  0.029524  0.043264  116.922610        4.437500
# 1285  vaughgr01      Greg     Vaughn  OF       1989     2003 -0.046351 -0.002875 -0.001613  0.029524  0.043264  116.922610        4.437500
# 1291  vaughgr01      Greg     Vaughn  OF       1989     2003 -0.046351 -0.002875 -0.001613  0.029524  0.043264  116.922610        4.437500
# 1288  vaughgr01      Greg     Vaughn  OF       1989     2003 -0.046351 -0.002875 -0.001613  0.029524  0.043264  116.922610        4.437500
# 1328  vaughgr01      Greg     Vaughn  OF       1989     2003 -0.046351 -0.002875 -0.001613  0.029524  0.043264  116.922610        4.437500
# 1303  vaughgr01      Greg     Vaughn  OF       1989     2003 -0.046351 -0.002875 -0.001613  0.029524  0.043264  116.922610        4.437500
# 1325  vaughgr01      Greg     Vaughn  OF       1989     2003 -0.046351 -0.002875 -0.001613  0.029524  0.043264  116.922610        4.437500
# 1322  vaughgr01      Greg     Vaughn  OF       1989     2003 -0.046351 -0.002875 -0.001613  0.029524  0.043264  116.922610        4.437500
# 1319  vaughgr01      Greg     Vaughn  OF       1989     2003 -0.046351 -0.002875 -0.001613  0.029524  0.043264  116.922610        4.437500
# 1316  vaughgr01      Greg     Vaughn  OF       1989     2003 -0.046351 -0.002875 -0.001613  0.029524  0.043264  116.922610        4.437500
# 1309  vaughgr01      Greg     Vaughn  OF       1989     2003 -0.046351 -0.002875 -0.001613  0.029524  0.043264  116.922610        4.437500
# 1310  vaughgr01      Greg     Vaughn  OF       1989     2003 -0.046351 -0.002875 -0.001613  0.029524  0.043264  116.922610        4.437500
# 1331  vaughgr01      Greg     Vaughn  OF       1989     2003 -0.046351 -0.002875 -0.001613  0.029524  0.043264  116.922610        4.437500
# 1313  vaughgr01      Greg     Vaughn  OF       1989     2003 -0.046351 -0.002875 -0.001613  0.029524  0.043264  116.922610        4.437500
# 364   durazer01   Erubiel     Durazo  OF       1999     2005 -0.005460  0.000087 -0.000804  0.019674  0.052152  114.328713        0.375000
# 368   durazer01   Erubiel     Durazo  OF       1999     2005 -0.005460  0.000087 -0.000804  0.019674  0.052152  114.328713        0.375000
# 631   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 634   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 669   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 670   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 673   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 677   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 680   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 639   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 638   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 643   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 658   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 625   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 624   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 665   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 662   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 657   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 649   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 646   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 628   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 616   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 612   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 608   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 604   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 601   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 587   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 591   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 593   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 597   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 620   henderi01    Rickey  Henderson  OF       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876        2.060000
# 68    branyru01   Russell    Branyan  OF       1998     2011 -0.060546 -0.008169 -0.003162  0.035207  0.028745  113.277386        0.900000
# 69    branyru01   Russell    Branyan  OF       1998     2011 -0.060546 -0.008169 -0.003162  0.035207  0.028745  113.277386        0.900000
# 74    branyru01   Russell    Branyan  OF       1998     2011 -0.060546 -0.008169 -0.003162  0.035207  0.028745  113.277386        0.900000
# 59    branyru01   Russell    Branyan  OF       1998     2011 -0.060546 -0.008169 -0.003162  0.035207  0.028745  113.277386        0.900000
# 54    branyru01   Russell    Branyan  OF       1998     2011 -0.060546 -0.008169 -0.003162  0.035207  0.028745  113.277386        0.900000
# 95    branyru01   Russell    Branyan  OF       1998     2011 -0.060546 -0.008169 -0.003162  0.035207  0.028745  113.277386        0.900000
# 96    branyru01   Russell    Branyan  OF       1998     2011 -0.060546 -0.008169 -0.003162  0.035207  0.028745  113.277386        0.900000
# 81    branyru01   Russell    Branyan  OF       1998     2011 -0.060546 -0.008169 -0.003162  0.035207  0.028745  113.277386        0.900000
# 86    branyru01   Russell    Branyan  OF       1998     2011 -0.060546 -0.008169 -0.003162  0.035207  0.028745  113.277386        0.900000
# 686   johnsni01      Nick    Johnson  OF       2001     2012 -0.024951  0.004029 -0.003655  0.004858  0.086579  112.830777        1.450000
# 953    penaca01    Carlos       Pena  OF       2001     2013 -0.047030 -0.006310 -0.000177  0.020492  0.044278  112.767155        2.900000
# 547   giambje01    Jeremy     Giambi  OF       1998     2003 -0.019964 -0.000054 -0.003218  0.009165  0.073271  111.443153        0.282500
# 556   giambje01    Jeremy     Giambi  OF       1998     2003 -0.019964 -0.000054 -0.003218  0.009165  0.073271  111.443153        0.282500
# 568   giambje01    Jeremy     Giambi  OF       1998     2003 -0.019964 -0.000054 -0.003218  0.009165  0.073271  111.443153        0.282500
# 564   giambje01    Jeremy     Giambi  OF       1998     2003 -0.019964 -0.000054 -0.003218  0.009165  0.073271  111.443153        0.282500
# 563   giambje01    Jeremy     Giambi  OF       1998     2003 -0.019964 -0.000054 -0.003218  0.009165  0.073271  111.443153        0.282500
# 543   giambje01    Jeremy     Giambi  OF       1998     2003 -0.019964 -0.000054 -0.003218  0.009165  0.073271  111.443153        0.282500
# 551   giambje01    Jeremy     Giambi  OF       1998     2003 -0.019964 -0.000054 -0.003218  0.009165  0.073271  111.443153        0.282500
# 427   edmonji01       Jim    Edmonds  OF       1993     2010 -0.026254  0.012312 -0.001148  0.023713  0.037640  111.184722        4.500000
# 434   edmonji01       Jim    Edmonds  OF       1993     2010 -0.026254  0.012312 -0.001148  0.023713  0.037640  111.184722        4.500000
# 433   edmonji01       Jim    Edmonds  OF       1993     2010 -0.026254  0.012312 -0.001148  0.023713  0.037640  111.184722        4.500000
# 426   edmonji01       Jim    Edmonds  OF       1993     2010 -0.026254  0.012312 -0.001148  0.023713  0.037640  111.184722        4.500000
# 411   edmonji01       Jim    Edmonds  OF       1993     2010 -0.026254  0.012312 -0.001148  0.023713  0.037640  111.184722        4.500000
# 386   edmonji01       Jim    Edmonds  OF       1993     2010 -0.026254  0.012312 -0.001148  0.023713  0.037640  111.184722        4.500000
# 389   edmonji01       Jim    Edmonds  OF       1993     2010 -0.026254  0.012312 -0.001148  0.023713  0.037640  111.184722        4.500000
# 405   edmonji01       Jim    Edmonds  OF       1993     2010 -0.026254  0.012312 -0.001148  0.023713  0.037640  111.184722        4.500000
# 402   edmonji01       Jim    Edmonds  OF       1993     2010 -0.026254  0.012312 -0.001148  0.023713  0.037640  111.184722        4.500000
# 399   edmonji01       Jim    Edmonds  OF       1993     2010 -0.026254  0.012312 -0.001148  0.023713  0.037640  111.184722        4.500000
# 395   edmonji01       Jim    Edmonds  OF       1993     2010 -0.026254  0.012312 -0.001148  0.023713  0.037640  111.184722        4.500000
# 393   edmonji01       Jim    Edmonds  OF       1993     2010 -0.026254  0.012312 -0.001148  0.023713  0.037640  111.184722        4.500000
# 423   edmonji01       Jim    Edmonds  OF       1993     2010 -0.026254  0.012312 -0.001148  0.023713  0.037640  111.184722        4.500000
# 383   edmonji01       Jim    Edmonds  OF       1993     2010 -0.026254  0.012312 -0.001148  0.023713  0.037640  111.184722        4.500000
# 420   edmonji01       Jim    Edmonds  OF       1993     2010 -0.026254  0.012312 -0.001148  0.023713  0.037640  111.184722        4.500000
# 417   edmonji01       Jim    Edmonds  OF       1993     2010 -0.026254  0.012312 -0.001148  0.023713  0.037640  111.184722        4.500000
# 415   edmonji01       Jim    Edmonds  OF       1993     2010 -0.026254  0.012312 -0.001148  0.023713  0.037640  111.184722        4.500000
# 378   edmonji01       Jim    Edmonds  OF       1993     2010 -0.026254  0.012312 -0.001148  0.023713  0.037640  111.184722        4.500000
# 407   edmonji01       Jim    Edmonds  OF       1993     2010 -0.026254  0.012312 -0.001148  0.023713  0.037640  111.184722        4.500000
# 769   kleskry01      Ryan     Klesko  OF       1992     2007 -0.009337  0.013285 -0.001010  0.015094  0.051450  110.440648        4.750000
# 774   kleskry01      Ryan     Klesko  OF       1992     2007 -0.009337  0.013285 -0.001010  0.015094  0.051450  110.440648        4.750000
# 781   kleskry01      Ryan     Klesko  OF       1992     2007 -0.009337  0.013285 -0.001010  0.015094  0.051450  110.440648        4.750000
# 785   kleskry01      Ryan     Klesko  OF       1992     2007 -0.009337  0.013285 -0.001010  0.015094  0.051450  110.440648        4.750000
# 788   kleskry01      Ryan     Klesko  OF       1992     2007 -0.009337  0.013285 -0.001010  0.015094  0.051450  110.440648        4.750000
# 766   kleskry01      Ryan     Klesko  OF       1992     2007 -0.009337  0.013285 -0.001010  0.015094  0.051450  110.440648        4.750000
# 753   kleskry01      Ryan     Klesko  OF       1992     2007 -0.009337  0.013285 -0.001010  0.015094  0.051450  110.440648        4.750000
# 747   kleskry01      Ryan     Klesko  OF       1992     2007 -0.009337  0.013285 -0.001010  0.015094  0.051450  110.440648        4.750000
# 750   kleskry01      Ryan     Klesko  OF       1992     2007 -0.009337  0.013285 -0.001010  0.015094  0.051450  110.440648        4.750000
# 756   kleskry01      Ryan     Klesko  OF       1992     2007 -0.009337  0.013285 -0.001010  0.015094  0.051450  110.440648        4.750000
# 759   kleskry01      Ryan     Klesko  OF       1992     2007 -0.009337  0.013285 -0.001010  0.015094  0.051450  110.440648        4.750000
# 762   kleskry01      Ryan     Klesko  OF       1992     2007 -0.009337  0.013285 -0.001010  0.015094  0.051450  110.440648        4.750000
# 812   lankfra01       Ray   Lankford  OF       1990     2004 -0.017340  0.012148  0.002976  0.010925  0.042474  109.550431        2.608334
# 816   lankfra01       Ray   Lankford  OF       1990     2004 -0.017340  0.012148  0.002976  0.010925  0.042474  109.550431        2.608334
# 820   lankfra01       Ray   Lankford  OF       1990     2004 -0.017340  0.012148  0.002976  0.010925  0.042474  109.550431        2.608334
# 821   lankfra01       Ray   Lankford  OF       1990     2004 -0.017340  0.012148  0.002976  0.010925  0.042474  109.550431        2.608334
# 791   lankfra01       Ray   Lankford  OF       1990     2004 -0.017340  0.012148  0.002976  0.010925  0.042474  109.550431        2.608334
# 808   lankfra01       Ray   Lankford  OF       1990     2004 -0.017340  0.012148  0.002976  0.010925  0.042474  109.550431        2.608334
# 793   lankfra01       Ray   Lankford  OF       1990     2004 -0.017340  0.012148  0.002976  0.010925  0.042474  109.550431        2.608334
# 795   lankfra01       Ray   Lankford  OF       1990     2004 -0.017340  0.012148  0.002976  0.010925  0.042474  109.550431        2.608334
# 797   lankfra01       Ray   Lankford  OF       1990     2004 -0.017340  0.012148  0.002976  0.010925  0.042474  109.550431        2.608334
# 799   lankfra01       Ray   Lankford  OF       1990     2004 -0.017340  0.012148  0.002976  0.010925  0.042474  109.550431        2.608334
# 801   lankfra01       Ray   Lankford  OF       1990     2004 -0.017340  0.012148  0.002976  0.010925  0.042474  109.550431        2.608334
# 803   lankfra01       Ray   Lankford  OF       1990     2004 -0.017340  0.012148  0.002976  0.010925  0.042474  109.550431        2.608334
# 805   lankfra01       Ray   Lankford  OF       1990     2004 -0.017340  0.012148  0.002976  0.010925  0.042474  109.550431        2.608334
# 826   lankfra01       Ray   Lankford  OF       1990     2004 -0.017340  0.012148  0.002976  0.010925  0.042474  109.550431        2.608334
# 829   lankfra01       Ray   Lankford  OF       1990     2004 -0.017340  0.012148  0.002976  0.010925  0.042474  109.550431        2.608334
# 195   burnije01    Jeromy    Burnitz  OF       1993     2006 -0.031766  0.002494 -0.000489  0.024583  0.027109  108.682327        3.612500
# 201   burnije01    Jeromy    Burnitz  OF       1993     2006 -0.031766  0.002494 -0.000489  0.024583  0.027109  108.682327        3.612500
# 192   burnije01    Jeromy    Burnitz  OF       1993     2006 -0.031766  0.002494 -0.000489  0.024583  0.027109  108.682327        3.612500
# 213   burnije01    Jeromy    Burnitz  OF       1993     2006 -0.031766  0.002494 -0.000489  0.024583  0.027109  108.682327        3.612500
# 211   burnije01    Jeromy    Burnitz  OF       1993     2006 -0.031766  0.002494 -0.000489  0.024583  0.027109  108.682327        3.612500
# 208   burnije01    Jeromy    Burnitz  OF       1993     2006 -0.031766  0.002494 -0.000489  0.024583  0.027109  108.682327        3.612500
# 202   burnije01    Jeromy    Burnitz  OF       1993     2006 -0.031766  0.002494 -0.000489  0.024583  0.027109  108.682327        3.612500
# 190   burnije01    Jeromy    Burnitz  OF       1993     2006 -0.031766  0.002494 -0.000489  0.024583  0.027109  108.682327        3.612500
# 187   burnije01    Jeromy    Burnitz  OF       1993     2006 -0.031766  0.002494 -0.000489  0.024583  0.027109  108.682327        3.612500
# 176   burnije01    Jeromy    Burnitz  OF       1993     2006 -0.031766  0.002494 -0.000489  0.024583  0.027109  108.682327        3.612500
# 175   burnije01    Jeromy    Burnitz  OF       1993     2006 -0.031766  0.002494 -0.000489  0.024583  0.027109  108.682327        3.612500
# 170   burnije01    Jeromy    Burnitz  OF       1993     2006 -0.031766  0.002494 -0.000489  0.024583  0.027109  108.682327        3.612500
# 165   burnije01    Jeromy    Burnitz  OF       1993     2006 -0.031766  0.002494 -0.000489  0.024583  0.027109  108.682327        3.612500
# 163   burnije01    Jeromy    Burnitz  OF       1993     2006 -0.031766  0.002494 -0.000489  0.024583  0.027109  108.682327        3.612500
# 181   burnije01    Jeromy    Burnitz  OF       1993     2006 -0.031766  0.002494 -0.000489  0.024583  0.027109  108.682327        3.612500
# 184   burnije01    Jeromy    Burnitz  OF       1993     2006 -0.031766  0.002494 -0.000489  0.024583  0.027109  108.682327        3.612500
# 703   jonesan01    Andruw      Jones  OF       1996     2012 -0.034147 -0.000105 -0.000749  0.025957  0.023475  107.914069        3.700000
# 706   jonesan01    Andruw      Jones  OF       1996     2012 -0.034147 -0.000105 -0.000749  0.025957  0.023475  107.914069        3.700000
# 708   jonesan01    Andruw      Jones  OF       1996     2012 -0.034147 -0.000105 -0.000749  0.025957  0.023475  107.914069        3.700000
# 710   jonesan01    Andruw      Jones  OF       1996     2012 -0.034147 -0.000105 -0.000749  0.025957  0.023475  107.914069        3.700000
# 712   jonesan01    Andruw      Jones  OF       1996     2012 -0.034147 -0.000105 -0.000749  0.025957  0.023475  107.914069        3.700000
# 715   jonesan01    Andruw      Jones  OF       1996     2012 -0.034147 -0.000105 -0.000749  0.025957  0.023475  107.914069        3.700000
# 717   jonesan01    Andruw      Jones  OF       1996     2012 -0.034147 -0.000105 -0.000749  0.025957  0.023475  107.914069        3.700000
# 738   jonesan01    Andruw      Jones  OF       1996     2012 -0.034147 -0.000105 -0.000749  0.025957  0.023475  107.914069        3.700000
# 733   jonesan01    Andruw      Jones  OF       1996     2012 -0.034147 -0.000105 -0.000749  0.025957  0.023475  107.914069        3.700000
# 729   jonesan01    Andruw      Jones  OF       1996     2012 -0.034147 -0.000105 -0.000749  0.025957  0.023475  107.914069        3.700000
# 726   jonesan01    Andruw      Jones  OF       1996     2012 -0.034147 -0.000105 -0.000749  0.025957  0.023475  107.914069        3.700000
# 724   jonesan01    Andruw      Jones  OF       1996     2012 -0.034147 -0.000105 -0.000749  0.025957  0.023475  107.914069        3.700000
# 721   jonesan01    Andruw      Jones  OF       1996     2012 -0.034147 -0.000105 -0.000749  0.025957  0.023475  107.914069        3.700000
# 719   jonesan01    Andruw      Jones  OF       1996     2012 -0.034147 -0.000105 -0.000749  0.025957  0.023475  107.914069        3.700000
# 699   jonesan01    Andruw      Jones  OF       1996     2012 -0.034147 -0.000105 -0.000749  0.025957  0.023475  107.914069        3.700000
# 906   palmera01    Rafael   Palmeiro  OF       1986     2005 -0.003482  0.007173 -0.001490  0.024908  0.027026  107.479925        4.906603
# 901   palmera01    Rafael   Palmeiro  OF       1986     2005 -0.003482  0.007173 -0.001490  0.024908  0.027026  107.479925        4.906603
# 897   palmera01    Rafael   Palmeiro  OF       1986     2005 -0.003482  0.007173 -0.001490  0.024908  0.027026  107.479925        4.906603
# 1396  wilkebr01      Brad  Wilkerson  OF       2001     2008 -0.032415  0.005331  0.002600  0.004167  0.049567  106.846578        3.000000
# 1402  wilkebr01      Brad  Wilkerson  OF       2001     2008 -0.032415  0.005331  0.002600  0.004167  0.049567  106.846578        3.000000
# 1391  wilkebr01      Brad  Wilkerson  OF       2001     2008 -0.032415  0.005331  0.002600  0.004167  0.049567  106.846578        3.000000
# 1407  wilkebr01      Brad  Wilkerson  OF       2001     2008 -0.032415  0.005331  0.002600  0.004167  0.049567  106.846578        3.000000
# 1408  wilkebr01      Brad  Wilkerson  OF       2001     2008 -0.032415  0.005331  0.002600  0.004167  0.049567  106.846578        3.000000
# 1372  wilkebr01      Brad  Wilkerson  OF       2001     2008 -0.032415  0.005331  0.002600  0.004167  0.049567  106.846578        3.000000
# 1376  wilkebr01      Brad  Wilkerson  OF       2001     2008 -0.032415  0.005331  0.002600  0.004167  0.049567  106.846578        3.000000
# 1381  wilkebr01      Brad  Wilkerson  OF       2001     2008 -0.032415  0.005331  0.002600  0.004167  0.049567  106.846578        3.000000
# 1386  wilkebr01      Brad  Wilkerson  OF       2001     2008 -0.032415  0.005331  0.002600  0.004167  0.049567  106.846578        3.000000
# 267    cruzjo02      Jose       Cruz  OF       1997     2008 -0.030572  0.003277  0.000847  0.009744  0.041833  105.453530        1.500000
# 270    cruzjo02      Jose       Cruz  OF       1997     2008 -0.030572  0.003277  0.000847  0.009744  0.041833  105.453530        1.500000
# 273    cruzjo02      Jose       Cruz  OF       1997     2008 -0.030572  0.003277  0.000847  0.009744  0.041833  105.453530        1.500000
# 278    cruzjo02      Jose       Cruz  OF       1997     2008 -0.030572  0.003277  0.000847  0.009744  0.041833  105.453530        1.500000
# 279    cruzjo02      Jose       Cruz  OF       1997     2008 -0.030572  0.003277  0.000847  0.009744  0.041833  105.453530        1.500000
# 280    cruzjo02      Jose       Cruz  OF       1997     2008 -0.030572  0.003277  0.000847  0.009744  0.041833  105.453530        1.500000
# 286    cruzjo02      Jose       Cruz  OF       1997     2008 -0.030572  0.003277  0.000847  0.009744  0.041833  105.453530        1.500000
# 290    cruzjo02      Jose       Cruz  OF       1997     2008 -0.030572  0.003277  0.000847  0.009744  0.041833  105.453530        1.500000
# 294    cruzjo02      Jose       Cruz  OF       1997     2008 -0.030572  0.003277  0.000847  0.009744  0.041833  105.453530        1.500000
# 263    cruzjo02      Jose       Cruz  OF       1997     2008 -0.030572  0.003277  0.000847  0.009744  0.041833  105.453530        1.500000
# 251    cruzjo02      Jose       Cruz  OF       1997     2008 -0.030572  0.003277  0.000847  0.009744  0.041833  105.453530        1.500000
# 252    cruzjo02      Jose       Cruz  OF       1997     2008 -0.030572  0.003277  0.000847  0.009744  0.041833  105.453530        1.500000
# 255    cruzjo02      Jose       Cruz  OF       1997     2008 -0.030572  0.003277  0.000847  0.009744  0.041833  105.453530        1.500000
# 258    cruzjo02      Jose       Cruz  OF       1997     2008 -0.030572  0.003277  0.000847  0.009744  0.041833  105.453530        1.500000
# 260    cruzjo02      Jose       Cruz  OF       1997     2008 -0.030572  0.003277  0.000847  0.009744  0.041833  105.453530        1.500000
# 1353  werthja01    Jayson      Werth  OF       2002     2013 -0.003548  0.004289  0.001283  0.010734  0.035110  104.193127        1.700000
# 1357  werthja01    Jayson      Werth  OF       2002     2013 -0.003548  0.004289  0.001283  0.010734  0.035110  104.193127        1.700000
# 1361  werthja01    Jayson      Werth  OF       2002     2013 -0.003548  0.004289  0.001283  0.010734  0.035110  104.193127        1.700000
# 1348  werthja01    Jayson      Werth  OF       2002     2013 -0.003548  0.004289  0.001283  0.010734  0.035110  104.193127        1.700000
# 1335  werthja01    Jayson      Werth  OF       2002     2013 -0.003548  0.004289  0.001283  0.010734  0.035110  104.193127        1.700000
# 1339  werthja01    Jayson      Werth  OF       2002     2013 -0.003548  0.004289  0.001283  0.010734  0.035110  104.193127        1.700000
# 1344  werthja01    Jayson      Werth  OF       2002     2013 -0.003548  0.004289  0.001283  0.010734  0.035110  104.193127        1.700000
# 1364  werthja01    Jayson      Werth  OF       2002     2013 -0.003548  0.004289  0.001283  0.010734  0.035110  104.193127        1.700000
# 478    gantro01       Ron       Gant  OF       1987     2003 -0.022975 -0.002619  0.001751  0.019113  0.017380  104.103154        3.166667
# 475    gantro01       Ron       Gant  OF       1987     2003 -0.022975 -0.002619  0.001751  0.019113  0.017380  104.103154        3.166667
# 473    gantro01       Ron       Gant  OF       1987     2003 -0.022975 -0.002619  0.001751  0.019113  0.017380  104.103154        3.166667
# 455    gantro01       Ron       Gant  OF       1987     2003 -0.022975 -0.002619  0.001751  0.019113  0.017380  104.103154        3.166667
# 458    gantro01       Ron       Gant  OF       1987     2003 -0.022975 -0.002619  0.001751  0.019113  0.017380  104.103154        3.166667
# 461    gantro01       Ron       Gant  OF       1987     2003 -0.022975 -0.002619  0.001751  0.019113  0.017380  104.103154        3.166667
# 464    gantro01       Ron       Gant  OF       1987     2003 -0.022975 -0.002619  0.001751  0.019113  0.017380  104.103154        3.166667
# 466    gantro01       Ron       Gant  OF       1987     2003 -0.022975 -0.002619  0.001751  0.019113  0.017380  104.103154        3.166667
# 468    gantro01       Ron       Gant  OF       1987     2003 -0.022975 -0.002619  0.001751  0.019113  0.017380  104.103154        3.166667
# 488    gantro01       Ron       Gant  OF       1987     2003 -0.022975 -0.002619  0.001751  0.019113  0.017380  104.103154        3.166667
# 496    gantro01       Ron       Gant  OF       1987     2003 -0.022975 -0.002619  0.001751  0.019113  0.017380  104.103154        3.166667
# 482    gantro01       Ron       Gant  OF       1987     2003 -0.022975 -0.002619  0.001751  0.019113  0.017380  104.103154        3.166667
# 492    gantro01       Ron       Gant  OF       1987     2003 -0.022975 -0.002619  0.001751  0.019113  0.017380  104.103154        3.166667
# 487    gantro01       Ron       Gant  OF       1987     2003 -0.022975 -0.002619  0.001751  0.019113  0.017380  104.103154        3.166667
# 483    gantro01       Ron       Gant  OF       1987     2003 -0.022975 -0.002619  0.001751  0.019113  0.017380  104.103154        3.166667
# 470    gantro01       Ron       Gant  OF       1987     2003 -0.022975 -0.002619  0.001751  0.019113  0.017380  104.103154        3.166667
# 108   burksel01     Ellis      Burks  OF       1987     2004  0.004979  0.004409  0.002066  0.019105  0.015918  103.975136        2.833333
# 149   burksel01     Ellis      Burks  OF       1987     2004  0.004979  0.004409  0.002066  0.019105  0.015918  103.975136        2.833333
# 153   burksel01     Ellis      Burks  OF       1987     2004  0.004979  0.004409  0.002066  0.019105  0.015918  103.975136        2.833333
# 157   burksel01     Ellis      Burks  OF       1987     2004  0.004979  0.004409  0.002066  0.019105  0.015918  103.975136        2.833333
# 111   burksel01     Ellis      Burks  OF       1987     2004  0.004979  0.004409  0.002066  0.019105  0.015918  103.975136        2.833333
# 125   burksel01     Ellis      Burks  OF       1987     2004  0.004979  0.004409  0.002066  0.019105  0.015918  103.975136        2.833333
# 123   burksel01     Ellis      Burks  OF       1987     2004  0.004979  0.004409  0.002066  0.019105  0.015918  103.975136        2.833333
# 120   burksel01     Ellis      Burks  OF       1987     2004  0.004979  0.004409  0.002066  0.019105  0.015918  103.975136        2.833333
# 117   burksel01     Ellis      Burks  OF       1987     2004  0.004979  0.004409  0.002066  0.019105  0.015918  103.975136        2.833333
# 114   burksel01     Ellis      Burks  OF       1987     2004  0.004979  0.004409  0.002066  0.019105  0.015918  103.975136        2.833333
# 128   burksel01     Ellis      Burks  OF       1987     2004  0.004979  0.004409  0.002066  0.019105  0.015918  103.975136        2.833333
# 146   burksel01     Ellis      Burks  OF       1987     2004  0.004979  0.004409  0.002066  0.019105  0.015918  103.975136        2.833333
# 143   burksel01     Ellis      Burks  OF       1987     2004  0.004979  0.004409  0.002066  0.019105  0.015918  103.975136        2.833333
# 142   burksel01     Ellis      Burks  OF       1987     2004  0.004979  0.004409  0.002066  0.019105  0.015918  103.975136        2.833333
# 138   burksel01     Ellis      Burks  OF       1987     2004  0.004979  0.004409  0.002066  0.019105  0.015918  103.975136        2.833333
# 135   burksel01     Ellis      Burks  OF       1987     2004  0.004979  0.004409  0.002066  0.019105  0.015918  103.975136        2.833333
# 131   burksel01     Ellis      Burks  OF       1987     2004  0.004979  0.004409  0.002066  0.019105  0.015918  103.975136        2.833333
# 160   burksel01     Ellis      Burks  OF       1987     2004  0.004979  0.004409  0.002066  0.019105  0.015918  103.975136        2.833333
# 237   clarkto02      Tony      Clark  OF       1996     2009 -0.026888 -0.002039 -0.003097  0.023315  0.026112  103.711848        0.900000
# 21    bellhma01      Mark   Bellhorn  OF       1997     2007 -0.054757 -0.012907 -0.000260 -0.005001  0.068008  103.276136        0.477500
# 14    bellhma01      Mark   Bellhorn  OF       1997     2007 -0.054757 -0.012907 -0.000260 -0.005001  0.068008  103.276136        0.477500
# 44    bellhma01      Mark   Bellhorn  OF       1997     2007 -0.054757 -0.012907 -0.000260 -0.005001  0.068008  103.276136        0.477500
# 28    bellhma01      Mark   Bellhorn  OF       1997     2007 -0.054757 -0.012907 -0.000260 -0.005001  0.068008  103.276136        0.477500
# 326   davanje02      Jeff    DaVanon  OF       1999     2007 -0.028303 -0.005905  0.006560 -0.001025  0.034596  102.865375        0.450000
# 331   davanje02      Jeff    DaVanon  OF       1999     2007 -0.028303 -0.005905  0.006560 -0.001025  0.034596  102.865375        0.450000
# 336   davanje02      Jeff    DaVanon  OF       1999     2007 -0.028303 -0.005905  0.006560 -0.001025  0.034596  102.865375        0.450000
# 341   davanje02      Jeff    DaVanon  OF       1999     2007 -0.028303 -0.005905  0.006560 -0.001025  0.034596  102.865375        0.450000
# 346   davanje02      Jeff    DaVanon  OF       1999     2007 -0.028303 -0.005905  0.006560 -0.001025  0.034596  102.865375        0.450000
# 351   davanje02      Jeff    DaVanon  OF       1999     2007 -0.028303 -0.005905  0.006560 -0.001025  0.034596  102.865375        0.450000
# 356   davanje02      Jeff    DaVanon  OF       1999     2007 -0.028303 -0.005905  0.006560 -0.001025  0.034596  102.865375        0.450000
# 357   davanje02      Jeff    DaVanon  OF       1999     2007 -0.028303 -0.005905  0.006560 -0.001025  0.034596  102.865375        0.450000
# 322   davanje02      Jeff    DaVanon  OF       1999     2007 -0.028303 -0.005905  0.006560 -0.001025  0.034596  102.865375        0.450000
# 1188  tuckemi01   Michael     Tucker  OF       1996     2006 -0.010893 -0.002518  0.005398  0.000892  0.034378  102.541207        1.600000
# 1213  tuckemi01   Michael     Tucker  OF       1996     2006 -0.010893 -0.002518  0.005398  0.000892  0.034378  102.541207        1.600000
# 1214  tuckemi01   Michael     Tucker  OF       1996     2006 -0.010893 -0.002518  0.005398  0.000892  0.034378  102.541207        1.600000
# 1222  tuckemi01   Michael     Tucker  OF       1996     2006 -0.010893 -0.002518  0.005398  0.000892  0.034378  102.541207        1.600000
# 1193  tuckemi01   Michael     Tucker  OF       1996     2006 -0.010893 -0.002518  0.005398  0.000892  0.034378  102.541207        1.600000
# 1227  tuckemi01   Michael     Tucker  OF       1996     2006 -0.010893 -0.002518  0.005398  0.000892  0.034378  102.541207        1.600000
# 1196  tuckemi01   Michael     Tucker  OF       1996     2006 -0.010893 -0.002518  0.005398  0.000892  0.034378  102.541207        1.600000
# 1198  tuckemi01   Michael     Tucker  OF       1996     2006 -0.010893 -0.002518  0.005398  0.000892  0.034378  102.541207        1.600000
# 1201  tuckemi01   Michael     Tucker  OF       1996     2006 -0.010893 -0.002518  0.005398  0.000892  0.034378  102.541207        1.600000
# 1206  tuckemi01   Michael     Tucker  OF       1996     2006 -0.010893 -0.002518  0.005398  0.000892  0.034378  102.541207        1.600000
# 1237  tuckemi01   Michael     Tucker  OF       1996     2006 -0.010893 -0.002518  0.005398  0.000892  0.034378  102.541207        1.600000
# 1241  tuckemi01   Michael     Tucker  OF       1996     2006 -0.010893 -0.002518  0.005398  0.000892  0.034378  102.541207        1.600000
# 1236  tuckemi01   Michael     Tucker  OF       1996     2006 -0.010893 -0.002518  0.005398  0.000892  0.034378  102.541207        1.600000
# 1230  tuckemi01   Michael     Tucker  OF       1996     2006 -0.010893 -0.002518  0.005398  0.000892  0.034378  102.541207        1.600000
# 304    custja01      Jack       Cust  OF       2001     2011 -0.005376 -0.014547 -0.004205  0.001715  0.066866  102.173746        1.455000
# 302    custja01      Jack       Cust  OF       2001     2011 -0.005376 -0.014547 -0.004205  0.001715  0.066866  102.173746        1.455000
# 299    custja01      Jack       Cust  OF       2001     2011 -0.005376 -0.014547 -0.004205  0.001715  0.066866  102.173746        1.455000
# 297    custja01      Jack       Cust  OF       2001     2011 -0.005376 -0.014547 -0.004205  0.001715  0.066866  102.173746        1.455000
# 307    custja01      Jack       Cust  OF       2001     2011 -0.005376 -0.014547 -0.004205  0.001715  0.066866  102.173746        1.455000
# 311    custja01      Jack       Cust  OF       2001     2011 -0.005376 -0.014547 -0.004205  0.001715  0.066866  102.173746        1.455000
# 314    custja01      Jack       Cust  OF       2001     2011 -0.005376 -0.014547 -0.004205  0.001715  0.066866  102.173746        1.455000
# 318    custja01      Jack       Cust  OF       2001     2011 -0.005376 -0.014547 -0.004205  0.001715  0.066866  102.173746        1.455000
# 1129  stairma01      Matt     Stairs  OF       1992     2011 -0.023954  0.007223 -0.003276  0.019133  0.029660  101.789287        0.875000
# 1124  stairma01      Matt     Stairs  OF       1992     2011 -0.023954  0.007223 -0.003276  0.019133  0.029660  101.789287        0.875000
# 1119  stairma01      Matt     Stairs  OF       1992     2011 -0.023954  0.007223 -0.003276  0.019133  0.029660  101.789287        0.875000
# 1135  stairma01      Matt     Stairs  OF       1992     2011 -0.023954  0.007223 -0.003276  0.019133  0.029660  101.789287        0.875000
# 1138  stairma01      Matt     Stairs  OF       1992     2011 -0.023954  0.007223 -0.003276  0.019133  0.029660  101.789287        0.875000
# 1099  stairma01      Matt     Stairs  OF       1992     2011 -0.023954  0.007223 -0.003276  0.019133  0.029660  101.789287        0.875000
# 1101  stairma01      Matt     Stairs  OF       1992     2011 -0.023954  0.007223 -0.003276  0.019133  0.029660  101.789287        0.875000
# 1104  stairma01      Matt     Stairs  OF       1992     2011 -0.023954  0.007223 -0.003276  0.019133  0.029660  101.789287        0.875000
# 1109  stairma01      Matt     Stairs  OF       1992     2011 -0.023954  0.007223 -0.003276  0.019133  0.029660  101.789287        0.875000
# 1114  stairma01      Matt     Stairs  OF       1992     2011 -0.023954  0.007223 -0.003276  0.019133  0.029660  101.789287        0.875000
# 1143  stairma01      Matt     Stairs  OF       1992     2011 -0.023954  0.007223 -0.003276  0.019133  0.029660  101.789287        0.875000
# 1167  stairma01      Matt     Stairs  OF       1992     2011 -0.023954  0.007223 -0.003276  0.019133  0.029660  101.789287        0.875000
# 1171  stairma01      Matt     Stairs  OF       1992     2011 -0.023954  0.007223 -0.003276  0.019133  0.029660  101.789287        0.875000
# 1172  stairma01      Matt     Stairs  OF       1992     2011 -0.023954  0.007223 -0.003276  0.019133  0.029660  101.789287        0.875000
# 1177  stairma01      Matt     Stairs  OF       1992     2011 -0.023954  0.007223 -0.003276  0.019133  0.029660  101.789287        0.875000
# 1182  stairma01      Matt     Stairs  OF       1992     2011 -0.023954  0.007223 -0.003276  0.019133  0.029660  101.789287        0.875000
# 1162  stairma01      Matt     Stairs  OF       1992     2011 -0.023954  0.007223 -0.003276  0.019133  0.029660  101.789287        0.875000
# 1148  stairma01      Matt     Stairs  OF       1992     2011 -0.023954  0.007223 -0.003276  0.019133  0.029660  101.789287        0.875000
# 1161  stairma01      Matt     Stairs  OF       1992     2011 -0.023954  0.007223 -0.003276  0.019133  0.029660  101.789287        0.875000
# 1153  stairma01      Matt     Stairs  OF       1992     2011 -0.023954  0.007223 -0.003276  0.019133  0.029660  101.789287        0.875000
# 1054  sandere02    Reggie    Sanders  OF       1991     2007 -0.015242  0.004555  0.001659  0.018735  0.008294  100.195711        2.787500
# 1052  sandere02    Reggie    Sanders  OF       1991     2007 -0.015242  0.004555  0.001659  0.018735  0.008294  100.195711        2.787500
# 1050  sandere02    Reggie    Sanders  OF       1991     2007 -0.015242  0.004555  0.001659  0.018735  0.008294  100.195711        2.787500
# 1047  sandere02    Reggie    Sanders  OF       1991     2007 -0.015242  0.004555  0.001659  0.018735  0.008294  100.195711        2.787500
# 1057  sandere02    Reggie    Sanders  OF       1991     2007 -0.015242  0.004555  0.001659  0.018735  0.008294  100.195711        2.787500
# 1096  sandere02    Reggie    Sanders  OF       1991     2007 -0.015242  0.004555  0.001659  0.018735  0.008294  100.195711        2.787500
# 1059  sandere02    Reggie    Sanders  OF       1991     2007 -0.015242  0.004555  0.001659  0.018735  0.008294  100.195711        2.787500
# 1075  sandere02    Reggie    Sanders  OF       1991     2007 -0.015242  0.004555  0.001659  0.018735  0.008294  100.195711        2.787500
# 1077  sandere02    Reggie    Sanders  OF       1991     2007 -0.015242  0.004555  0.001659  0.018735  0.008294  100.195711        2.787500
# 1081  sandere02    Reggie    Sanders  OF       1991     2007 -0.015242  0.004555  0.001659  0.018735  0.008294  100.195711        2.787500
# 1085  sandere02    Reggie    Sanders  OF       1991     2007 -0.015242  0.004555  0.001659  0.018735  0.008294  100.195711        2.787500
# 1089  sandere02    Reggie    Sanders  OF       1991     2007 -0.015242  0.004555  0.001659  0.018735  0.008294  100.195711        2.787500
# 1092  sandere02    Reggie    Sanders  OF       1991     2007 -0.015242  0.004555  0.001659  0.018735  0.008294  100.195711        2.787500
# 1073  sandere02    Reggie    Sanders  OF       1991     2007 -0.015242  0.004555  0.001659  0.018735  0.008294  100.195711        2.787500
# 1064  sandere02    Reggie    Sanders  OF       1991     2007 -0.015242  0.004555  0.001659  0.018735  0.008294  100.195711        2.787500
# 1061  sandere02    Reggie    Sanders  OF       1991     2007 -0.015242  0.004555  0.001659  0.018735  0.008294  100.195711        2.787500
# 1069  sandere02    Reggie    Sanders  OF       1991     2007 -0.015242  0.004555  0.001659  0.018735  0.008294  100.195711        2.787500
# 1258  valenjo03      Jose   Valentin  OF       1992     2007 -0.039928 -0.002966  0.003635  0.010808  0.015571  100.017383        2.136095
# 1273  valenjo03      Jose   Valentin  OF       1992     2007 -0.039928 -0.002966  0.003635  0.010808  0.015571  100.017383        2.136095
# 1279  valenjo03      Jose   Valentin  OF       1992     2007 -0.039928 -0.002966  0.003635  0.010808  0.015571  100.017383        2.136095
# 1263  valenjo03      Jose   Valentin  OF       1992     2007 -0.039928 -0.002966  0.003635  0.010808  0.015571  100.017383        2.136095

# %%
## Here's my dream team:
names = ["riosar01", "giambja01", "pridecu01", "vaughgr01", "estalbo02", "durazer01", "branyru01", "bellhma01", "valenjo03", "henderi01"   ]
pos   = ["CF"     ,  "DH"       , "RF",         "LF",        "C",         "1B",        "3B",        "2B",        "SS",     "OF"]

ttt = pd.DataFrame({'playerID': names, 'position':pos})
ttt
#players1 = players.loc[players.yearID.isin(yearsWant)]
mtSal = mt1.loc[mt1.playerID.isin(names)][["medianSalaries", "playerID"]]
mtSal = mtSal.drop_duplicates()
mtSal.medianSalaries.sum() # this is under 20 million

mtt = pd.merge(ttt, mtSal)
finalTeam = pd.merge(mtt, playerNames)
fin = pd.merge(finalTeam, sal1)
fin
# Out:
#     playerID position  medianSalaries nameFirst   nameLast  startYear  endYear    1BRate    2BRate    3BRate    HRRate    BBRate         OPW
# 0   riosar01       CF        0.310000   Armando       Rios       1998     2003  0.017385 -0.010822 -0.000768  0.024351  0.083089  129.705775
# 1  giambja01       DH        3.103333     Jason     Giambi       1996     2013 -0.025094 -0.000428 -0.003872  0.026118  0.075882  123.850785
# 2  pridecu01       RF        0.183000    Curtis      Pride       1993     2006 -0.049817  0.006043  0.010724  0.049465 -0.024976  122.434454
# 3  vaughgr01       LF        4.437500      Greg     Vaughn       1989     2003 -0.046351 -0.002875 -0.001613  0.029524  0.043264  116.922610
# 4  estalbo02        C        0.260000     Bobby  Estalella       1996     2004 -0.054029 -0.018654 -0.002475  0.028767  0.042107  114.714759
# 5  durazer01       1B        0.375000   Erubiel     Durazo       1999     2005 -0.005460  0.000087 -0.000804  0.019674  0.052152  114.328713
# 6  branyru01       3B        0.900000   Russell    Branyan       1998     2011 -0.060546 -0.008169 -0.003162  0.035207  0.028745  113.277386
# 7  bellhma01       2B        0.477500      Mark   Bellhorn       1997     2007 -0.054757 -0.012907 -0.000260 -0.005001  0.068008  103.276136
# 8  valenjo03       SS        2.136095      Jose   Valentin       1992     2007 -0.039928 -0.002966  0.003635  0.010808  0.015571  100.017383
# 9  henderi01       OF        2.060000    Rickey  Henderson       1979     2003  0.001370 -0.005509 -0.000692  0.001107  0.086441  114.214876

# %% [markdown]
# #### Problem 1(m)
# What do these players outperform in? Singles, doubles, triples HR or BB?

# %%
pd.DataFrame(fin.sum(axis = 0))
# Out:
#                                                                 0
# playerID        riosar01giambja01pridecu01vaughgr01estalbo02du...
# position                                      CFDHRFLFC1B3B2BSSOF
# medianSalaries                                           14.24243
# nameFirst       ArmandoJasonCurtisGregBobbyErubielRussellMarkJ...
# nameLast        RiosGiambiPrideVaughnEstalellaDurazoBranyanBel...
# startYear                                                   19937
# endYear                                                     20062
# 1BRate                                                 -0.3172275
# 2BRate                                                -0.05620023
# 3BRate                                               0.0007120565
# HRRate                                                  0.2200199
# BBRate                                                  0.4702845
# OPW                                                      1152.743

# %% [markdown]
# ** Your answer here: **
#
# The data frame above shows the sums of the columns for my dream team. On average, this team would outperform others in triples, home runs, and base on balls.

# %% [markdown]
# ## Discussion for Problem 1
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---

# %% [markdown]
# # Problem 2:  $k$-Nearest Neighbors and Cross Validation
#
# What is the optimal $k$ for predicting species using $k$-nearest neighbor classification
# on the four features provided by the iris dataset.
#
# In this problem you will get to know the famous iris data set, and use cross validation to select the optimal $k$ for a $k$-nearest neighbor classification. This problem set makes heavy use of the [sklearn](http://scikit-learn.org/stable/) library. In addition to Pandas, it is one of the most useful libraries for data scientists! After completing this homework assignment you will know all the basics to get started with your own machine learning projects in sklearn.
#
# Future lectures will give further background information on different classifiers and their specific strengths and weaknesses, but when you have the basics for sklearn down, changing the classifier will boil down to exchanging one to two lines of code.
#
# The data set is so popular, that sklearn provides an extra function to load it:

# %%
#load the iris data set
iris = sklearn.datasets.load_iris()

X = iris.data # measurements
Y = iris.target # species classifications

#print X.shape(), Y.shape()
dat = pd.DataFrame(X)
dat["Species"] = Y

print( X.shape, Y.shape)
# Out:
# (150, 4) (150,)

# %% [markdown]
# #### Problem 2(a)
# Split the data into a train and a test set. Use a random selection of 33% of the samples as test data. Sklearn provides the [`train_test_split`](http://scikit-learn.org/stable/modules/generated/sklearn.cross_validation.train_test_split.html) function for this purpose. Print the dimensions of all the train and test data sets you have created.

# %%
trts = sklearn.cross_validation.train_test_split(dat, test_size = 0.33)
tst = pd.DataFrame(trts[1])
tr = pd.DataFrame(trts[0])

print( tst.shape, tr.shape)
# Out:
# (50, 5) (100, 5)

# %% [markdown]
# #### Problem 2(b)
#
# Examine the data further by looking at the projections to the first two principal components of the data. Use the [`TruncatedSVD`](http://scikit-learn.org/stable/modules/generated/sklearn.decomposition.TruncatedSVD.html) function for this purpose, and create a scatter plot. Use the colors on the scatter plot to represent the different classes in the target data.

# %%
### Your code here ###
XD = tr[[0,1,2,3]] #this is the training set --- it shouldn't be the test set.

XD = XD.copy() - np.mean(XD) # subract colmeans

# %%
svd = sklearn.decomposition.TruncatedSVD(n_components=2)
fit1 = svd.fit(XD) 

fit2 = fit1.transform(XD)
f2 = pd.DataFrame(fit2)

# plot a scatterplot
x = f2[[0]]
y = f2[[1]]

#set figure and axis
fig = plt.figure(figsize=(8, 5))
ax = Subplot(fig, 111)
fig.add_subplot(ax)

#plot
ax.scatter(x, y, s=40, c=tr[[4]],  alpha = 1, lw = 0.2, cmap="autumn") 
plt.xlabel("component1") # xlabel
plt.ylabel("component2") # ylabel
plt.title("Irises split by two principal components") # title
#plt.xlim(0, 25)

#do not display top and right axes
ax.axis["right"].set_visible(False)
ax.axis["top"].set_visible(False)
#plt.legend(loc = 1)


plt.show()

# %% [markdown]
# #### Problem 2(c)
#
# In the lecture we discussed how to use cross validation to estimate the optimal value for $k$ (the number of nearest neighbors to base the classification on). Use ***ten fold cross validation*** to estimate the optimal value for $k$ for the iris data set.
#
# **Note**: For your convenience sklearn does not only include the [KNN classifier](http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html), but also a [grid search function](http://scikit-learn.org/stable/modules/generated/sklearn.grid_search.GridSearchCV.html#sklearn.grid_search.GridSearchCV). The function is called grid search, because if you have to optimize more than one parameter, it is common practice to define a range of possible values for each parameter. An exhaustive search then runs over the complete grid defined by all the possible parameter combinations. This can get very computation heavy, but luckily our KNN classifier only requires tuning of a single parameter for this problem set.

# %%
xx = fit2
yy = np.array(tr[4])

# %%
nnei = 2
neigh = sklearn.neighbors.KNeighborsClassifier(n_neighbors=nnei)
neigh.fit(xx,yy)
#neigh.predict([[5]])
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            n_neighbors=2, p=2, weights='uniform')

# %%
## plot boundary

def visualize_decision_boundary(classifier, xmin, xmax, ymin, 
                                ymax, step_size=0.02, 
                                cmap="Pastel1"):
    
    xx, yy = np.meshgrid(np.arange(xmin, xmax, step_size),
                         np.arange(ymin, ymax, step_size))
    colors = classifier.predict(np.c_[xx.ravel(), yy.ravel()])
    colors = colors.reshape(xx.shape)
    ax = plt.subplot(111)
    ax.pcolormesh(xx, yy, colors, cmap=cmap)
    return ax


# now visualize the boundary
boundary_vis = visualize_decision_boundary(classifier=neigh, 
                                           xmin=-4,xmax=5,
                                           ymin=-1.5,ymax=1.5,
                                           step_size=0.02)

# and plot our data points
boundary_vis.scatter(x, y, s=40, c=tr[[4]],  alpha = 1, lw = 0.2, cmap="autumn") 
#boundary_vis.scatter(x2[:,0],x2[:,1], c='b', s=100)
plt.show()

# %%
k = 4
knn = sklearn.neighbors.KNeighborsClassifier(n_neighbors=k, 
                                             weights = 'uniform')
knn.fit(xx,yy)
y_hat = knn.predict(xx)

confusion_matrix = sklearn.metrics.confusion_matrix(yy, y_hat)
print (confusion_matrix)


# Show confusion matrix in a separate window
def show_confusion_matrix(confusion_matrix):
    plt.matshow(confusion_matrix, cmap=plt.cm.Greys_r)
    plt.title('Confusion matrix')
    plt.colorbar()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    
show_confusion_matrix(confusion_matrix)
# Out:
# [[34  0  0]
#  [ 0 32  1]
#  [ 0  1 32]]

# %%
## evaluate accuracy
sklearn.metrics.accuracy_score(yy, y_hat, normalize=True)
# Out:
# 0.97999999999999998

# %%
# look at accuracy for k on training set -- I know this is wrong
def accuracy_for_k(k,x,y):
    knn = sklearn.neighbors.KNeighborsClassifier(n_neighbors=k, 
                                             weights = 'uniform')
    knn.fit(x,y)
    y_hat = knn.predict(x)
    return sklearn.metrics.accuracy_score(y, y_hat, normalize=True)

## Why is this code inefficient -- it's appending
acc_values = []
k_values = xrange(1,50,1)
for k in k_values:
    acc_values.append(accuracy_for_k(k=k,x=xx,y=yy))
    
plt.plot(k_values, acc_values)
plt.xlabel('Value of k')
plt.ylabel('Accuracy')
fig_train_acc = plt.gcf()

# %%
## evaluate accuracy for k, using validation set -- another method of cross validation
def accuracy_for_k_val(k,x,y, random_state=99):
    split_data = sklearn.cross_validation.train_test_split(
                        x,y, test_size=0.33, random_state=random_state)
    x_train, x_val, y_train, y_val = split_data
    knn = sklearn.neighbors.KNeighborsClassifier(n_neighbors=k, 
                                             weights = 'uniform')
    knn.fit(x_train,y_train)
    y_hat = knn.predict(x_val)
    return sklearn.metrics.accuracy_score(y_val, y_hat, 
                                          normalize=True)



## cross validation
k_values = range(1,50,1)

np.random.seed(seed=99)
random_seeds = np.random.randint(1000, size=50)

values = np.zeros((len(k_values),random_seeds.shape[0]))
for k, c_k in zip(k_values, range(len(k_values))):
    counter_rs = 0
    for rs,c_rs in zip(random_seeds, range(random_seeds.shape[0])):
        value = accuracy_for_k_val(k=k,x=xx,y=yy,
                                   random_state=rs)
        values[c_k,c_rs] = value
       
#set figure and axis
fig = plt.figure(figsize=(8, 5))
ax = Subplot(fig, 111)
fig.add_subplot(ax)

# plot data
sns.tsplot(values.T)
plt.xlabel('k')
plt.ylabel('accuracy')

#do not display top and right axes
ax.axis["right"].set_visible(False)
ax.axis["top"].set_visible(False)
plt.show()

# %%
def accuracy_for_k_val_kFold(k, x_train, x_test, y_train, y_test, random_state=99):
    knn = sklearn.neighbors.KNeighborsClassifier(n_neighbors=k, 
                                             weights = 'uniform')
    knn.fit(x_train,y_train)
    y_hat = knn.predict(x_test)
    return sklearn.metrics.accuracy_score(y_test, y_hat, normalize=True)

# %%
## grid search

# To apply an classifier on this data, we need to flatten the image, to
# turn the data in a (samples, feature) matrix:
X = fit2
Y = tr[4]

# Set the parameters by cross-validation
tuned_parameters = {'n_neighbors': range(1,50)}

clf = GridSearchCV(sklearn.neighbors.KNeighborsClassifier(), tuned_parameters, cv=10, scoring='accuracy')
clf.fit(X, Y)

print("Best parameters set found on training set:")
print()
print(clf.best_estimator_)
print()
print("Grid scores on training set:")
print()

sc = [None] * len(range(1,51))
e = [None] * len(sc)
ctr = 1
for params, mean_score, scores in clf.grid_scores_:
    print("%0.3f (+/-%0.03f) for %r"
          % (mean_score, scores.std()/math.sqrt(10), params))
    sc[ctr] = mean_score
    e[ctr] = scores.std()/math.sqrt(10)
    ctr = ctr + 1
# Out:
# Best parameters set found on training set:
#
# KNeighborsClassifier(algorithm=auto, leaf_size=30, metric=minkowski,
#            n_neighbors=3, p=2, weights=uniform)
#
# Grid scores on training set:
#
# 0.940 (+/-0.025) for {'n_neighbors': 1}
# 0.940 (+/-0.021) for {'n_neighbors': 2}
# 0.980 (+/-0.013) for {'n_neighbors': 3}
# 0.970 (+/-0.014) for {'n_neighbors': 4}
# 0.960 (+/-0.021) for {'n_neighbors': 5}
# 0.940 (+/-0.021) for {'n_neighbors': 6}
# 0.960 (+/-0.021) for {'n_neighbors': 7}
# 0.950 (+/-0.021) for {'n_neighbors': 8}
# 0.960 (+/-0.021) for {'n_neighbors': 9}
# 0.950 (+/-0.021) for {'n_neighbors': 10}
# 0.950 (+/-0.021) for {'n_neighbors': 11}
# 0.950 (+/-0.021) for {'n_neighbors': 12}
# 0.950 (+/-0.021) for {'n_neighbors': 13}
# 0.950 (+/-0.021) for {'n_neighbors': 14}
# 0.950 (+/-0.021) for {'n_neighbors': 15}
# 0.940 (+/-0.029) for {'n_neighbors': 16}
# 0.930 (+/-0.028) for {'n_neighbors': 17}
# 0.930 (+/-0.028) for {'n_neighbors': 18}
# 0.950 (+/-0.021) for {'n_neighbors': 19}
# 0.920 (+/-0.028) for {'n_neighbors': 20}
# 0.930 (+/-0.028) for {'n_neighbors': 21}
# 0.910 (+/-0.036) for {'n_neighbors': 22}
# 0.930 (+/-0.038) for {'n_neighbors': 23}
# 0.910 (+/-0.039) for {'n_neighbors': 24}
# 0.920 (+/-0.037) for {'n_neighbors': 25}
# 0.900 (+/-0.028) for {'n_neighbors': 26}
# 0.920 (+/-0.031) for {'n_neighbors': 27}
# 0.890 (+/-0.030) for {'n_neighbors': 28}
# 0.910 (+/-0.030) for {'n_neighbors': 29}
# 0.880 (+/-0.031) for {'n_neighbors': 30}
# 0.900 (+/-0.028) for {'n_neighbors': 31}
# 0.890 (+/-0.030) for {'n_neighbors': 32}
# 0.900 (+/-0.028) for {'n_neighbors': 33}
# 0.900 (+/-0.028) for {'n_neighbors': 34}
# 0.900 (+/-0.028) for {'n_neighbors': 35}
# 0.900 (+/-0.028) for {'n_neighbors': 36}
# 0.900 (+/-0.028) for {'n_neighbors': 37}
# 0.890 (+/-0.033) for {'n_neighbors': 38}
# 0.900 (+/-0.028) for {'n_neighbors': 39}
# 0.880 (+/-0.034) for {'n_neighbors': 40}
# 0.870 (+/-0.032) for {'n_neighbors': 41}
# 0.880 (+/-0.034) for {'n_neighbors': 42}
# 0.870 (+/-0.032) for {'n_neighbors': 43}
# 0.870 (+/-0.035) for {'n_neighbors': 44}
# 0.870 (+/-0.035) for {'n_neighbors': 45}
# 0.860 (+/-0.040) for {'n_neighbors': 46}
# 0.880 (+/-0.031) for {'n_neighbors': 47}
# 0.870 (+/-0.035) for {'n_neighbors': 48}
# 0.880 (+/-0.031) for {'n_neighbors': 49}

# %% [markdown]
# #### Problem 2(d)
#
# Visualize the result by plotting the score results verus values for $k$.

# %%
#set figure and axis
fig = plt.figure(figsize=(8, 5))
ax = Subplot(fig, 111)
fig.add_subplot(ax)

#plot
#plt.plot(sc)
sc[0] = 0
e[0] = 0

plt.errorbar(range(1, 51), sc, e, linestyle='None', marker='o', label = "mean + standard error")
plt.xlabel("k") # xlabel
plt.ylabel("accuracy") # ylabel
plt.title("10-fold cross validation for k-values") # title
plt.ylim(.8, 1.05)
plt.legend(loc = 3)

#do not display top and right axes
ax.axis["right"].set_visible(False)
ax.axis["top"].set_visible(False)



plt.show()

# %% [markdown]
# Verify that the grid search has indeed chosen the right parameter value for $k$.

# %%
## split data into 10 groups for 10-fold cross validation -- sort of the brute-force way
X = fit2
y = tr[4]


## evaluate accuracy for 10-fold cross validation
kf = KFold(len(Y), n_folds = 10)
acc1 = [None]*60
for tt in range(1,len(acc1), 1):
    acc = [None]*10
    ctr = 0
    for train_index, test_index in kf:
        #print("TRAIN:", train_index, "TEST:", test_index)
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        acc[ctr] =  accuracy_for_k_val_kFold(tt, X_train, X_test, y_train, y_test)
        ctr = ctr + 1
    acc1[tt] =  np.array(acc).mean()
    
bestAcc = np.array(acc1).max()
gg = list(acc1)
kShouldBe = gg.index(bestAcc)  ## this gives the highest accuracy
print("Best choice for k, from non-grid-search method is ", kShouldBe, "which agrees with grid search")
# Out:
# Best choice for k, from non-grid-search method is  3 which agrees with grid search

# %% [markdown]
# #### Problem 2(e)
#
# Test the performance of our tuned KNN classifier on the test set.

# %%
### Your code here ###
XT = tst[[0,1,2,3]] #this is the test set
XT = XT.copy() - np.mean(XT) # subract colmeans
y_true = np.array(tst[4]) # this is the true y-values
svd = sklearn.decomposition.TruncatedSVD(n_components=2) # convert to 2 principal components
fit3 = svd.fit(XT) 
fit4 = fit1.transform(XT)
xxt = fit4 # principal components for test set

# %%
y_true, y_pred = y_true, clf.predict(xxt)
correct = (y_true == y_pred)
percentRight = correct.sum()/float(len(correct))
print(percentRight)
# Out:
# 0.96

# %% [markdown]
# ## Discussion for Problem 2
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---

# %% [markdown]
# # Problem 3: The Curse and Blessing of Higher Dimensions
#
# In this problem we will investigate the influence of higher dimensional spaces on the classification. The data set is again one of the standard data sets from sklearn. The [digits data set](http://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_digits.html) is similar to the MNIST data set discussed in the lecture. The main difference is, that each digit is represented by an 8x8 pixel image patch, which is considerably smaller than the 28x28 pixels from MNIST. In addition, the gray values are restricted to 16 different values (4 bit), instead of 256 (8 bit) for MNIST.
#
# First we again load our data set.

# %%
digits = sklearn.datasets.load_digits()

X = digits.data  
Y = digits.target

print(X.shape, Y.shape)
# Out:
# (1797, 64) (1797,)

# %% [markdown]
# #### Problem 3(a)
#
# Start with the same steps as in Problem 2. Split the data into train and test set. Use 33% of the samples as test data. Print the dimensions of all the train and test data sets you created.

# %%
### Your code here ###

# %% [markdown]
# #### Problem 3(b)
#
# Similar to Problem 2(b), create a scatter plot of the projections to the first two PCs.  Use the colors on the scatter plot to represent the different classes in the target data. How well can we separate the classes?
#
# **Hint**: Use a `Colormap` in matplotlib to represent the diferent classes in the target data.

# %%
### Your code here ###

# %% [markdown]
# Create individual scatter plots using only two classes at a time to explore which classes are most difficult to distinguish in terms of class separability.  You do not need to create scatter plots for all pairwise comparisons, but at least show one.

# %%
### Your code here ###

# %% [markdown]
# Give a brief interpretation of the scatter plot. Which classes look like hard to distinguish? Do both feature dimensions contribute to the class separability?

# %% [markdown]
# ** Your answer here: **

# %% [markdown]
# #### Problem 3(c)
#
# Write a **ten-fold cross validation** to estimate the optimal value for $k$ for the digits data set. *However*, this time we are interested in the influence of the number of dimensions we project the data down as well.
#
# Extend the cross validation as done for the iris data set, to optimize $k$ for different dimensional projections of the data. Create a boxplot showing test scores for the optimal $k$ for each $d$-dimensional subspace with $d$ ranging from one to ten. The plot should have the scores on the y-axis and the different dimensions $d$ on the x-axis. You can use your favorite plot function for the boxplots. [Seaborn](http://web.stanford.edu/~mwaskom/software/seaborn/index.html) is worth having a look at though. It is a great library for statistical visualization and of course also comes with a [`boxplot`](http://web.stanford.edu/~mwaskom/software/seaborn/generated/seaborn.boxplot.html) function that has simple means for changing the labels on the x-axis.

# %%
### Your cross validation and evaluation code here ###

# %%
### Your boxplot code here ###

# %% [markdown]
# Write a short interpretation of the generated plot, answering the following questions:
#
# * What trend do you see in the plot for increasing dimensions?
#
# * Why do you think this is happening?

# %% [markdown]
# ** Your answer here: **

# %% [markdown]
# #### Problem 3(d)
#
# **For AC209 Students**: Change the boxplot we generated above to also show the optimal value for $k$ chosen by the cross validation grid search.

# %%
### Your code here ###

# %% [markdown]
# Write a short interpretation answering the following questions:
#
# * Which trend do you observe for the optimal value of $k$?
#
# * Why do you think this is happening?

# %% [markdown]
# ** Your answer here: **

# %% [markdown]
# ## Discussion for Problem 3
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---

# %% [markdown]
# # Submission Instructions
#
# To submit your homework, create a folder named **lastname_firstinitial_hw#** and place your IPython notebooks, data files, and any other files in this folder. Your IPython Notebooks should be completely executed with the results visible in the notebook. We should not have to run any code.  Compress the folder (please use .zip compression) and submit to the CS109 dropbox in the appropriate folder. *If we cannot access your work because these directions are not followed correctly, we will not grade your work.*
